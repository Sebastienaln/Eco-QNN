# %%
import numpy as np
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit
from qiskit.circuit.library import zz_feature_map, real_amplitudes
from qiskit_machine_learning.algorithms import VQC
from qiskit_algorithms.optimizers import L_BFGS_B
from qiskit_algorithms.optimizers import COBYLA
from qiskit_algorithms.optimizers import SPSA 
from qiskit_aer import AerSimulator
from sklearn.model_selection import train_test_split

# %%
# ── Configuration ─────────────────────────────────────────────────────────────

# Dataset
n          = 500    # Number of generated points
TEST_SIZE  = 0.2    # Fraction used for test set
SEED       = 1      # Random seed (data split & optimizer init)
N_DIM      = 6     # Features dimension

# Optimization
MAXITER    = 200     # minimizer max iterations
optimizer = COBYLA(maxiter=MAXITER) 
# ──────────────────────────────────────────────────────────────────────────────

# %%
def generate_nsphere_data(n_samples, n_dim, radius=None):
    # Génération de points entre -1 et 1
    X = np.random.uniform(-1, 1, (n_samples, n_dim))    
    # Le rayon par défaut est choisi pour équilibrer les classes
    if radius is None:
        radius = np.sqrt(n_dim / 3) 
        
    # Calcul de la norme euclidienne au carré
    dist_sq = np.sum(X**2, axis=1)
    y = (dist_sq >= radius**2).astype(int)
    
    return X, y, radius

# %%
X, y, R = generate_nsphere_data(n_samples=n, n_dim=N_DIM)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print(X_train.shape, y_train.shape)
# Out:
# (400, 6) (400,)

# %% [markdown]
# ## VQC

# %%
iteration = 0
def callback(*args):
    global iteration
    iteration += 1 
    print(f"Iteration {iteration}")

# %%
feature_map = zz_feature_map(feature_dimension=N_DIM, reps=2)
ansatz = real_amplitudes(num_qubits=N_DIM, reps=2)

vqc = VQC(feature_map=feature_map, ansatz=ansatz, optimizer=optimizer, callback=callback)
# Out:
# No gradient function provided, creating a gradient function. If your Sampler requires transpilation, please provide a pass manager.

# %% [markdown]
# ## Training

# %%
print(f"Entraînement sur une {N_DIM}-sphère...")
vqc.fit(X_train, y_train )
# Out:
# Entraînement sur une 6-sphère...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 2
#       1 print(f"Entraînement sur une {N_DIM}-sphère...")
# ----> 2 vqc.fit(X_train, y_train )
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_machine_learning\algorithms\trainable_model.py:202, in TrainableModel.fit(self, X, y)
#     199 if not self._warm_start:
#     200     self._fit_result = None
# --> 202 self._fit_result = self._fit_internal(X, y)
#     203 return self
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_machine_learning\algorithms\classifiers\vqc.py:194, in VQC._fit_internal(self, X, y)
#     191     self._neural_network.set_interpret(self.interpret, num_classes)
#     193 function = self._create_objective(X, y)
# --> 194 return self._minimize(function)
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_machine_learning\algorithms\trainable_model.py:299, in TrainableModel._minimize(self, function)
#     295     optimizer_result = self._optimizer(  # type: ignore[call-arg]
#     296         fun=objective, x0=initial_point, jac=function.gradient
#     297     )
#     298 else:
# --> 299     optimizer_result = self._optimizer.minimize(
#     300         fun=objective,
#     301         x0=initial_point,
#     302         jac=function.gradient,  # type: ignore[arg-type]
#     303     )
#     304 return optimizer_result
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_algorithms\optimizers\scipy_optimizer.py:162, in SciPyOptimizer.minimize(self, fun, x0, jac, bounds)
#     159     swapped_deprecated_args = True
#     160     self._options["maxfun"] = self._options.pop("maxiter")
# --> 162 raw_result = minimize(
#     163     fun=fun,
#     164     x0=x0,
#     165     method=self._method,
#     166     jac=jac,
#     167     bounds=bounds,
#     168     options=self._options,
#     169     **self._kwargs,
#     170 )
#     171 if swapped_deprecated_args:
#     172     self._options["maxiter"] = self._options.pop("maxfun")
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_minimize.py:744, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     741     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     742                         **options)
#     743 elif meth == 'cobyla':
# --> 744     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     745                            bounds=bounds, **options)
#     746 elif meth == 'cobyqa':
#     747     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     748                            **options)
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_cobyla_py.py:293, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     290         callback(np.copy(x))
#     292 info = np.zeros(4, np.float64)
# --> 293 xopt, info = cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     294                               rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     295                               dinfo=info, callback=wrapped_callback)
#     297 if info[3] > catol:
#     298     # Check constraint violation
#     299     info[0] = 4
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_cobyla_py.py:281, in _minimize_cobyla.<locals>.calcfc(x, con)
#     280 def calcfc(x, con):
# --> 281     f = sf.fun(x)
#     282     i = 0
#     283     for size, c in izip(cons_lengths, constraints):
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_differentiable_functions.py:326, in ScalarFunction.fun(self, x)
#     324 if not np.array_equal(x, self.x):
#     325     self._update_x(x)
# --> 326 self._update_fun()
#     327 return self.f
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_differentiable_functions.py:295, in ScalarFunction._update_fun(self)
#     293 def _update_fun(self):
#     294     if not self.f_updated:
# --> 295         fx = self._wrapped_fun(self.x)
#     296         if fx < self._lowest_f:
#     297             self._lowest_x = self.x
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_differentiable_functions.py:21, in _wrapper_fun.<locals>.wrapped(x)
#      17 ncalls[0] += 1
#      18 # Send a copy because the user may overwrite it.
#      19 # Overwriting results in undefined behaviour because
#      20 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 21 fx = fun(np.copy(x), *args)
#      22 # Make sure the function returns a true scalar
#      23 if not np.isscalar(fx):
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_machine_learning\algorithms\trainable_model.py:274, in TrainableModel._get_objective.<locals>.objective(objective_weights)
#     273 def objective(objective_weights):
# --> 274     objective_value = function.objective(objective_weights)
#     275     if isinstance(self._optimizer, SciPyOptimizer):
#     276         self._callback(objective_weights, objective_value)
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_machine_learning\algorithms\objective_functions.py:190, in OneHotObjectiveFunction.objective(self, weights)
#     188 def objective(self, weights: np.ndarray) -> float:
#     189     # probabilities is of shape (N, num_outputs)
# --> 190     probs = self._neural_network_forward(weights)
#     191     # float(...) is for mypy compliance
#     192     value = float(np.sum(self._loss(probs, self._y)) / self._num_samples)
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_machine_learning\algorithms\objective_functions.py:101, in ObjectiveFunction._neural_network_forward(self, weights)
#      96 # if we get the same weights, we don't compute the forward pass again.
#      97 if self._last_forward_weights is None or (
#      98     not np.all(np.isclose(weights, self._last_forward_weights))
#      99 ):
#     100     # compute forward and cache the results for re-use in backward
# --> 101     self._last_forward = self._neural_network.forward(self._X, weights)
#     102     # a copy avoids keeping a reference to the same array, so we are sure we have
#     103     # different arrays on the next iteration.
#     104     self._last_forward_weights = np.copy(weights)
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_machine_learning\neural_networks\neural_network.py:229, in NeuralNetwork.forward(self, input_data, weights)
#     227 input_, shape = self._validate_input(input_data)
#     228 weights_ = self._validate_weights(weights)
# --> 229 output_data = self._forward(input_, weights_)
#     230 return self._validate_forward_output(output_data, shape)
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_machine_learning\neural_networks\sampler_qnn.py:486, in SamplerQNN._forward(self, input_data, weights)
#     484 except Exception as exc:
#     485     raise QiskitMachineLearningError(f"Sampler job failed: {exc}") from exc
# --> 486 result = self._postprocess(num_samples, results)
#     487 return result
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_machine_learning\neural_networks\sampler_qnn.py:372, in SamplerQNN._postprocess(self, num_samples, result)
#     366 # alternative field names some builds expose
#     367 if (
#     368     counts_i is None
#     369     and hasattr(pub.data, "meas")
#     370     and hasattr(pub.data.meas, "get_counts")
#     371 ):
# --> 372     counts_i = pub.data.meas.get_counts(i)
#     374 # absolute fallback (aggregated; avoids crash but will degrade accuracy)
#     375 if counts_i is None:
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_machine_learning\primitives\sampler.py:411, in ExactProbNDArray.get_counts(self, loc, shots)
#     409 if loc is not None:
#     410     elem = cast(ExactProbArray, self._arr[loc])
# --> 411     return elem.get_counts(shots=shots)
#     413 total: dict[str, int] = {}
#     415 # for exact non-dyadic distributions this raises; caller can use get_probabilities instead
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_machine_learning\primitives\sampler.py:263, in ExactProbArray.get_counts(self, shots)
#     261 ks = []
#     262 for p in probs.values():
# --> 263     k = dyadic_k(p)
#     264     if k is None:
#     265         raise ValueError(
#     266             "ExactProbArray.get_counts: distribution is not dyadic; "
#     267             "use get_probabilities() for exact values."
#     268         )
#
# File c:\Users\Gnomp\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_machine_learning\primitives\sampler.py:257, in ExactProbArray.get_counts.<locals>.dyadic_k(p, tol, kmax)
#     255 for k in range(kmax + 1):
#     256     m = round(p * (1 << k))
# --> 257     if abs(p - m / float(1 << k)) <= tol:
#     258         return k
#     259 return None
#
# KeyboardInterrupt:

# %% [markdown]
# ## VQC Results

# %%
accuracy = vqc.score(X_test, y_test)
y_pred = vqc.predict(X_test)
print(f"Précision sur le test: {accuracy*100} %")
# Out:
# Précision sur le test: 100.0 %

# %% [markdown]
# ### VQC circuit

# %%
# 1. Visualiser comment les données N-dim sont encodées
print("--- FEATURE MAP ---")
vqc.feature_map.draw('mpl')
# Out:
# --- FEATURE MAP ---

# %%
# 2. Visualiser la structure d'entraînement (les couches de rotation et CNOT)
print("--- ANSATZ ---")
vqc.ansatz.draw('mpl')
# Out:
# --- ANSATZ ---

# %% [markdown]
# ### Visualisation si dim=2 ou 3

# %%
def plot_2d() : 
    pred1 = X_test[y_pred == 1]
    pred0 = X_test[y_pred == 0]

    plt.scatter(pred0[:,0],pred0[:,1], color = 'red', label='pred0')
    plt.scatter(pred1[:,0],pred1[:,1], color = 'blue', label='pred1')


    circle_rad = np.sqrt(N_DIM/3) # rayon par défaut, à modifier si le rayon est changé
    circle = plt.Circle((0, 0), circle_rad, color='black', fill=False, 
                        linestyle='--', linewidth=2, label='Frontière réelle')
    plt.gca().add_artist(circle)

    # Configuration du graphique
    plt.title(f"Visualisation des performances ({accuracy*100}%)")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.axhline(0, color='black', linewidth=0.5, alpha=0.5)
    plt.axvline(0, color='black', linewidth=0.5, alpha=0.5)
    plt.legend(loc='upper right')
    plt.axis('equal')
    plt.grid(True, alpha=0.3)
    plt.show()
    
def plot_3d() :
    from mpl_toolkits.mplot3d import Axes3D
 
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    
    # Masques pour séparer les résultats
    pred1 = X_test[y_pred == 1]
    pred0 = X_test[y_pred == 0]

    ax.scatter(pred0[:,0],pred0[:,1],pred0[:,2], color = 'red', label='pred0')
    ax.scatter(pred1[:,0],pred1[:,1],pred1[:,2], color = 'blue', label='pred1')
    

    # Dessiner l'enveloppe de la sphère théorique (Wireframe)
    u = np.linspace(0, 2 * np.pi, 30)
    v = np.linspace(0, np.pi, 30)
    x_sphere = R * np.outer(np.cos(u), np.sin(v))
    y_sphere = R * np.outer(np.sin(u), np.sin(v))
    z_sphere = R * np.outer(np.ones(np.size(u)), np.cos(v))
    ax.plot_wireframe(x_sphere, y_sphere, z_sphere, color="black", alpha=0.1, linewidths=0.5)

    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title(f"Visualisation 3D : Accuracy {accuracy*100}%")
    ax.legend()
    plt.show()

# %%
if N_DIM == 2 : 
    plot_2d()
    
elif N_DIM == 3 : 
    plot_3d()

# %% [markdown]
# ## Re-uploading baseline (1 qubit, seulement pour la 3-sphère)
#
# On garde le VQC actuel, puis on ajoute un second entraînement inspiré du notebook `circuit.ipynb`. Cette seconde partie n'est exécutée que si `N_DIM == 3`, car on veut tester l'idée qu'un seul qubit peut suffire avec du re-uploading.

# %%
from scipy.optimize import minimize
from qiskit_aer import StatevectorSimulator

# %%
# Hyperparamètres du modèle re-uploading
RC_REUPLOAD = 8      # nombre de couches de re-uploading
MAXITER_REUPLOAD = 150
USE_REUPLOAD = (N_DIM == 3)

print(f"USE_REUPLOAD = {USE_REUPLOAD}")
if not USE_REUPLOAD:
    print("Le bloc re-uploading ci-dessous est prévu pour N_DIM = 3.")

# %%
def U_su2_reupload(qc, theta_block, omega_block, x, qubit=0):
    """
    Une couche de type U(theta + omega * x) sur un seul qubit.
    Pour N_DIM=3, on injecte directement les 3 coordonnées.
    """
    qc.u(
        theta_block[0] + omega_block[0] * x[0],
        theta_block[1] + omega_block[1] * x[1],
        theta_block[2] + omega_block[2] * x[2],
        qubit
    )

def create_reupload_circuit(x, theta, omega, measure=False):
    qc = QuantumCircuit(1)
    for r in range(RC_REUPLOAD):
        qc.h(0)
        U_su2_reupload(qc, theta[r], omega[r], x, qubit=0)
    if measure:
        qc.measure_all()
    return qc

def get_reupload_probs_batch(circuits):
    sim = StatevectorSimulator()
    probs = []
    for qc in circuits:
        sv = sim.run(qc).result().get_statevector()
        p0 = float(np.abs(sv[0])**2)
        p1 = float(np.abs(sv[1])**2)
        probs.append((p0, p1))
    return probs

# %%
def reupload_cost_weighted(params, X, y):
    """
    Même esprit que dans circuit.ipynb :
    - theta : paramètres "de traitement"
    - omega : poids qui multiplient les features avant réinjection
    - alphas : poids de classe pour équilibrer le coût
    """
    theta = params[:3 * RC_REUPLOAD].reshape(RC_REUPLOAD, 3)
    omega = params[3 * RC_REUPLOAD:6 * RC_REUPLOAD].reshape(RC_REUPLOAD, 3)
    alphas = params[6 * RC_REUPLOAD:]  # alpha_0, alpha_1

    circuits = [create_reupload_circuit(x, theta, omega, measure=False) for x in X]
    probs = get_reupload_probs_batch(circuits)

    total_cost = 0.0
    for i, y_target in enumerate(y):
        p0, p1 = probs[i]
        y_expected = (1.0, 0.0) if y_target == 0 else (0.0, 1.0)
        weight = alphas[y_target] ** 2
        total_cost += weight * ((p0 - y_expected[0])**2 + (p1 - y_expected[1])**2)

    return 0.5 * total_cost / len(X)

def unpack_reupload_params(params):
    theta = params[:3 * RC_REUPLOAD].reshape(RC_REUPLOAD, 3)
    omega = params[3 * RC_REUPLOAD:6 * RC_REUPLOAD].reshape(RC_REUPLOAD, 3)
    alphas = params[6 * RC_REUPLOAD:]
    return theta, omega, alphas

def optimize_reupload_parameters(X, y):
    rng = np.random.default_rng(SEED)
    init = rng.uniform(-np.pi, np.pi, size=6 * RC_REUPLOAD + 2)

    reupload_cost_history = []

    def objective(params):
        cost = reupload_cost_weighted(params, X, y)
        reupload_cost_history.append(cost)
        print(f"Iteration {len(reupload_cost_history):3d} | cost = {cost:.6f}")
        return cost

    res = minimize(
        objective,
        init,
        method="COBYLA",
        options={"maxiter": MAXITER_REUPLOAD}
    )

    theta_opt, omega_opt, alphas_opt = unpack_reupload_params(res.x)
    return res, theta_opt, omega_opt, alphas_opt, reupload_cost_history

def predict_reupload_batch(X, theta, omega):
    circuits = [create_reupload_circuit(x, theta, omega, measure=False) for x in X]
    probs = get_reupload_probs_batch(circuits)
    return np.array([0 if p0 >= p1 else 1 for p0, p1 in probs])

def evaluate_reupload(X, y, theta, omega):
    y_pred = predict_reupload_batch(X, theta, omega)
    accuracy = np.mean(y_pred == y)
    return accuracy, y_pred

# %%
if USE_REUPLOAD:
    print("Entraînement du modèle re-uploading (1 qubit)...")
    reupload_res, theta_re, omega_re, alpha_re, reupload_cost_history = optimize_reupload_parameters(X_train, y_train)

    reupload_accuracy, y_pred_reupload = evaluate_reupload(X_test, y_test, theta_re, omega_re)
    print(f"Précision test re-uploading : {100 * reupload_accuracy:.2f}%")
else:
    print("Bloc non exécuté car N_DIM != 3")

# %%
if USE_REUPLOAD:
    print("Circuit re-uploading appris :")
    qc_reupload = create_reupload_circuit(X_train[0], theta_re, omega_re, measure=False)
    qc_reupload.draw("mpl")

# %%
if USE_REUPLOAD:
    plt.figure(figsize=(7, 4))
    plt.plot(reupload_cost_history)
    plt.xlabel("Itération")
    plt.ylabel("Cost")
    plt.title("Courbe de coût - modèle re-uploading (1 qubit)")
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
def plot_3d_reupload():
    pred1 = X_test[y_pred_reupload == 1]
    pred0 = X_test[y_pred_reupload == 0]

    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(pred0[:, 0], pred0[:, 1], pred0[:, 2], color='red', label='pred0', alpha=0.7)
    ax.scatter(pred1[:, 0], pred1[:, 1], pred1[:, 2], color='blue', label='pred1', alpha=0.7)

    ax.set_xlabel('x1')
    ax.set_ylabel('x2')
    ax.set_zlabel('x3')
    ax.set_title('Prédictions du modèle re-uploading (1 qubit)')
    ax.legend()
    plt.show()

if USE_REUPLOAD and N_DIM == 3:
    plot_3d_reupload()

# %%
if USE_REUPLOAD:
    print("=== Comparaison rapide ===")
    print(f"VQC classique  ({N_DIM} qubits) : {accuracy * 100:.2f}%")
    print(f"Re-uploading   (1 qubit)  : {reupload_accuracy * 100:.2f}%")
