# %%
import numpy as np
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit
from qiskit.circuit.library import zz_feature_map, real_amplitudes
from qiskit_machine_learning.algorithms import VQC
from qiskit_algorithms.optimizers import L_BFGS_B
from qiskit_algorithms.optimizers import COBYLA
from qiskit_algorithms.optimizers import SPSA 
from qiskit_aer import AerSimulator
from sklearn.model_selection import train_test_split

# %%
# ── Configuration ─────────────────────────────────────────────────────────────

# Dataset
n          = 900    # Number of generated points
TEST_SIZE  = 0.2    # Fraction used for test set
SEED       = 1      # Random seed (data split & optimizer init)
N_DIM      = 3     # Features dimension

# Optimization
MAXITER    = 200     # minimizer max iterations
optimizer = COBYLA(maxiter=MAXITER) 
# ──────────────────────────────────────────────────────────────────────────────

# %%
def generate_nsphere_data(n_samples, n_dim, radius=None):
    # Génération de points entre -1 et 1
    X = np.random.uniform(-1, 1, (n_samples, n_dim))    
    # Le rayon par défaut est choisi pour équilibrer les classes
    if radius is None:
        radius = np.sqrt(n_dim / 3) 
        
    # Calcul de la norme euclidienne au carré
    dist_sq = np.sum(X**2, axis=1)
    y = (dist_sq >= radius**2).astype(int)
    
    return X, y, radius

# %%
X, y, R = generate_nsphere_data(n_samples=n, n_dim=N_DIM)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print(X_train.shape, y_train.shape)
# Out:
# (400, 3) (400,)

# %% [markdown]
# ## VQC

# %%
iteration = 0
def callback(*args):
    global iteration
    iteration += 1 
    print(f"Iteration {iteration}")

# %%
feature_map = zz_feature_map(feature_dimension=N_DIM, reps=2)
ansatz = real_amplitudes(num_qubits=N_DIM, reps=2)

vqc = VQC(feature_map=feature_map, ansatz=ansatz, optimizer=optimizer, callback=callback)
# Out:
# No gradient function provided, creating a gradient function. If your Sampler requires transpilation, please provide a pass manager.

# %% [markdown]
# ## Training

# %%
print(f"Entraînement sur une {N_DIM}-sphère...")
vqc.fit(X_train, y_train )
# Out:
# Entraînement sur une 3-sphère...

# %% [markdown]
# ## VQC Results

# %%
accuracy = vqc.score(X_test, y_test)
y_pred = vqc.predict(X_test)
print(f"Précision sur le test: {accuracy*100} %")
# Out:
# ---------------------------------------------------------------------------
# QiskitMachineLearningError                Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 accuracy = vqc.score(X_test, y_test)
#       2 y_pred = vqc.predict(X_test)
#       3 print(f"Précision sur le test: {accuracy*100} %")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\qiskit_machine_learning\algorithms\classifiers\neural_network_classifier.py:214, in NeuralNetworkClassifier.score(self, X, y, sample_weight)
#     213 def score(self, X: np.ndarray, y: np.ndarray, sample_weight: np.ndarray | None = None) -> float:
# --> 214     return ClassifierMixin.score(self, X, y, sample_weight)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:566, in ClassifierMixin.score(self, X, y, sample_weight)
#     541 """
#     542 Return :ref:`accuracy <accuracy_score>` on provided data and labels.
#     543
#    (...)    562     Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     563 """
#     564 from sklearn.metrics import accuracy_score
# --> 566 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\qiskit_machine_learning\algorithms\classifiers\neural_network_classifier.py:165, in NeuralNetworkClassifier.predict(self, X)
#     142 def predict(self, X: np.ndarray) -> np.ndarray:
#     143     """
#     144     Perform classification on samples in X.
#     145
#    (...)    163             - If the pre-computed kernel matrix has the wrong shape and/or dimension.
#     164     """
# --> 165     self._check_fitted()
#     166     X, _ = self._validate_input(X)
#     168     if self._neural_network.output_shape == (1,):
#     169         # Binary classification
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\qiskit_machine_learning\algorithms\trainable_model.py:182, in TrainableModel._check_fitted(self)
#     180 def _check_fitted(self) -> None:
#     181     if self._fit_result is None:
# --> 182         raise QiskitMachineLearningError("The model has not been fitted yet")
#
# QiskitMachineLearningError: 'The model has not been fitted yet'

# %% [markdown]
# ### VQC circuit

# %%
# 1. Visualiser comment les données N-dim sont encodées
print("--- FEATURE MAP ---")
vqc.feature_map.draw('mpl')
# Out:
# --- FEATURE MAP ---

# %%
# 2. Visualiser la structure d'entraînement (les couches de rotation et CNOT)
print("--- ANSATZ ---")
vqc.ansatz.draw('mpl')
# Out:
# --- ANSATZ ---

# %% [markdown]
# ### Visualisation si dim=2 ou 3

# %%
def plot_2d() : 
    pred1 = X_test[y_pred == 1]
    pred0 = X_test[y_pred == 0]

    plt.scatter(pred0[:,0],pred0[:,1], color = 'red', label='pred0')
    plt.scatter(pred1[:,0],pred1[:,1], color = 'blue', label='pred1')


    circle_rad = np.sqrt(N_DIM/3) # rayon par défaut, à modifier si le rayon est changé
    circle = plt.Circle((0, 0), circle_rad, color='black', fill=False, 
                        linestyle='--', linewidth=2, label='Frontière réelle')
    plt.gca().add_artist(circle)

    # Configuration du graphique
    plt.title(f"Visualisation des performances ({accuracy*100}%)")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.axhline(0, color='black', linewidth=0.5, alpha=0.5)
    plt.axvline(0, color='black', linewidth=0.5, alpha=0.5)
    plt.legend(loc='upper right')
    plt.axis('equal')
    plt.grid(True, alpha=0.3)
    plt.show()
    
def plot_3d() :
    from mpl_toolkits.mplot3d import Axes3D
 
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    
    # Masques pour séparer les résultats
    pred1 = X_test[y_pred == 1]
    pred0 = X_test[y_pred == 0]

    ax.scatter(pred0[:,0],pred0[:,1],pred0[:,2], color = 'red', label='pred0')
    ax.scatter(pred1[:,0],pred1[:,1],pred1[:,2], color = 'blue', label='pred1')
    

    # Dessiner l'enveloppe de la sphère théorique (Wireframe)
    u = np.linspace(0, 2 * np.pi, 30)
    v = np.linspace(0, np.pi, 30)
    x_sphere = R * np.outer(np.cos(u), np.sin(v))
    y_sphere = R * np.outer(np.sin(u), np.sin(v))
    z_sphere = R * np.outer(np.ones(np.size(u)), np.cos(v))
    ax.plot_wireframe(x_sphere, y_sphere, z_sphere, color="black", alpha=0.1, linewidths=0.5)

    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title(f"Visualisation 3D : Accuracy {accuracy*100}%")
    ax.legend()
    plt.show()

# %%
if N_DIM == 2 : 
    plot_2d()
    
elif N_DIM == 3 : 
    plot_3d()

# %% [markdown]
# ## Re-uploading baseline (1 qubit, seulement pour la 3-sphère)
#
# On garde le VQC actuel, puis on ajoute un second entraînement inspiré du notebook `circuit.ipynb`. Cette seconde partie n'est exécutée que si `N_DIM == 3`, car on veut tester l'idée qu'un seul qubit peut suffire avec du re-uploading.

# %%
from scipy.optimize import minimize
from qiskit_aer import StatevectorSimulator

# %%
# Hyperparamètres du modèle re-uploading
RC_REUPLOAD = 10    # nombre de couches de re-uploading
MAXITER_REUPLOAD = 150
USE_REUPLOAD = (N_DIM == 3)

print(f"USE_REUPLOAD = {USE_REUPLOAD}")
if not USE_REUPLOAD:
    print("Le bloc re-uploading ci-dessous est prévu pour N_DIM = 3.")
# Out:
# USE_REUPLOAD = True

# %%
def U_su2_reupload(qc, theta_block, omega_block, x, qubit=0):
    """
    Une couche de type U(theta + omega * x) sur un seul qubit.
    Pour N_DIM=3, on injecte directement les 3 coordonnées.
    """
    qc.u(
        theta_block[0] + omega_block[0] * x[0],
        theta_block[1] + omega_block[1] * x[1],
        theta_block[2] + omega_block[2] * x[2],
        qubit
    )

def create_reupload_circuit(x, theta, omega, measure=False):
    qc = QuantumCircuit(1)
    for r in range(RC_REUPLOAD):
        qc.h(0)
        U_su2_reupload(qc, theta[r], omega[r], x, qubit=0)
    if measure:
        qc.measure_all()
    return qc

def get_reupload_probs_batch(circuits):
    sim = StatevectorSimulator()
    probs = []
    for qc in circuits:
        sv = sim.run(qc).result().get_statevector()
        p0 = float(np.abs(sv[0])**2)
        p1 = float(np.abs(sv[1])**2)
        probs.append((p0, p1))
    return probs

# %%
def reupload_cost_weighted(params, X, y):
    """
    Même esprit que dans circuit.ipynb :
    - theta : paramètres "de traitement"
    - omega : poids qui multiplient les features avant réinjection
    - alphas : poids de classe pour équilibrer le coût
    """
    theta = params[:3 * RC_REUPLOAD].reshape(RC_REUPLOAD, 3)
    omega = params[3 * RC_REUPLOAD:6 * RC_REUPLOAD].reshape(RC_REUPLOAD, 3)
    alphas = params[6 * RC_REUPLOAD:]  # alpha_0, alpha_1

    circuits = [create_reupload_circuit(x, theta, omega, measure=False) for x in X]
    probs = get_reupload_probs_batch(circuits)

    total_cost = 0.0
    for i, y_target in enumerate(y):
        p0, p1 = probs[i]
        y_expected = (1.0, 0.0) if y_target == 0 else (0.0, 1.0)
        weight = alphas[y_target] ** 2
        total_cost += weight * ((p0 - y_expected[0])**2 + (p1 - y_expected[1])**2)

    return 0.5 * total_cost / len(X)

def unpack_reupload_params(params):
    theta = params[:3 * RC_REUPLOAD].reshape(RC_REUPLOAD, 3)
    omega = params[3 * RC_REUPLOAD:6 * RC_REUPLOAD].reshape(RC_REUPLOAD, 3)
    alphas = params[6 * RC_REUPLOAD:]
    return theta, omega, alphas

def optimize_reupload_parameters(X, y):
    rng = np.random.default_rng(SEED)
    init = rng.uniform(-np.pi, np.pi, size=6 * RC_REUPLOAD + 2)

    reupload_cost_history = []

    def objective(params):
        cost = reupload_cost_weighted(params, X, y)
        reupload_cost_history.append(cost)
        print(f"Iteration {len(reupload_cost_history):3d} | cost = {cost:.6f}")
        return cost

    res = minimize(
        objective,
        init,
        method="COBYLA",
        options={"maxiter": MAXITER_REUPLOAD}
    )

    theta_opt, omega_opt, alphas_opt = unpack_reupload_params(res.x)
    return res, theta_opt, omega_opt, alphas_opt, reupload_cost_history

def predict_reupload_batch(X, theta, omega):
    circuits = [create_reupload_circuit(x, theta, omega, measure=False) for x in X]
    probs = get_reupload_probs_batch(circuits)
    return np.array([0 if p0 >= p1 else 1 for p0, p1 in probs])

def evaluate_reupload(X, y, theta, omega):
    y_pred = predict_reupload_batch(X, theta, omega)
    accuracy = np.mean(y_pred == y)
    return accuracy, y_pred

# %%
if USE_REUPLOAD:
    print("Entraînement du modèle re-uploading (1 qubit)...")
    reupload_res, theta_re, omega_re, alpha_re, reupload_cost_history = optimize_reupload_parameters(X_train, y_train)

    reupload_accuracy, y_pred_reupload = evaluate_reupload(X_test, y_test, theta_re, omega_re)
    print(f"Précision test re-uploading : {100 * reupload_accuracy:.2f}%")
else:
    print("Bloc non exécuté car N_DIM != 3")
# Out:
# Entraînement du modèle re-uploading (1 qubit)...
# Iteration   1 | cost = 1.618284
# Iteration   2 | cost = 1.754676
# Iteration   3 | cost = 1.558271
# Iteration   4 | cost = 1.776716
# Iteration   5 | cost = 1.556408
# Iteration   6 | cost = 1.692856
# Iteration   7 | cost = 1.626045
# Iteration   8 | cost = 1.472107
# Iteration   9 | cost = 1.685387
# Iteration  10 | cost = 1.757095
# Iteration  11 | cost = 1.446626
# Iteration  12 | cost = 1.612723
# Iteration  13 | cost = 1.497109
# Iteration  14 | cost = 1.390423
# Iteration  15 | cost = 1.533870
# Iteration  16 | cost = 1.474686
# Iteration  17 | cost = 1.395117
# Iteration  18 | cost = 1.454716
# Iteration  19 | cost = 1.545517
# Iteration  20 | cost = 1.451946
# Iteration  21 | cost = 1.565243
# Iteration  22 | cost = 1.600370
# Iteration  23 | cost = 1.798219
# Iteration  24 | cost = 1.600478
# Iteration  25 | cost = 1.598673
# Iteration  26 | cost = 1.513223
# Iteration  27 | cost = 1.410250
# Iteration  28 | cost = 1.437764
# Iteration  29 | cost = 1.569581
# Iteration  30 | cost = 1.390423
# Iteration  31 | cost = 1.489342
# Iteration  32 | cost = 1.381576
# Iteration  33 | cost = 1.516228
# Iteration  34 | cost = 1.608600
# Iteration  35 | cost = 1.384588
# Iteration  36 | cost = 1.386285
# Iteration  37 | cost = 1.468139
# Iteration  38 | cost = 1.589673
# Iteration  39 | cost = 1.458061
# Iteration  40 | cost = 1.482432
# Iteration  41 | cost = 1.365300
# Iteration  42 | cost = 1.372695
# Iteration  43 | cost = 1.368973
# Iteration  44 | cost = 1.425128
# Iteration  45 | cost = 1.452794
# Iteration  46 | cost = 1.404697
# Iteration  47 | cost = 1.551006
# Iteration  48 | cost = 1.346138
# Iteration  49 | cost = 1.317226
# Iteration  50 | cost = 1.456733
# Iteration  51 | cost = 1.427051
# Iteration  52 | cost = 1.341875
# Iteration  53 | cost = 1.435427
# Iteration  54 | cost = 1.344978
# Iteration  55 | cost = 1.225800
# Iteration  56 | cost = 1.194584
# Iteration  57 | cost = 1.105285
# Iteration  58 | cost = 1.407440
# Iteration  59 | cost = 1.134169
# Iteration  60 | cost = 1.105285
# Iteration  61 | cost = 1.169470
# Iteration  62 | cost = 0.860248
# Iteration  63 | cost = 0.407112
# Iteration  64 | cost = 0.263933
# Iteration  65 | cost = 0.206953
# Iteration  66 | cost = 0.213280
# Iteration  67 | cost = 0.235836
# Iteration  68 | cost = 0.219729
# Iteration  69 | cost = 0.219129
# Iteration  70 | cost = 0.243915
# Iteration  71 | cost = 0.217144
# Iteration  72 | cost = 0.225064
# Iteration  73 | cost = 0.253402
# Iteration  74 | cost = 0.211100
# Iteration  75 | cost = 0.185251
# Iteration  76 | cost = 0.178515
# Iteration  77 | cost = 0.192817
# Iteration  78 | cost = 0.174138
# Iteration  79 | cost = 0.138144
# Iteration  80 | cost = 0.152990
# Iteration  81 | cost = 0.119698
# Iteration  82 | cost = 0.132519
# Iteration  83 | cost = 0.109767
# Iteration  84 | cost = 0.110566
# Iteration  85 | cost = 0.096528
# Iteration  86 | cost = 0.092033
# Iteration  87 | cost = 0.084026
# Iteration  88 | cost = 0.091408
# Iteration  89 | cost = 0.062994
# Iteration  90 | cost = 0.061293
# Iteration  91 | cost = 0.062305
# Iteration  92 | cost = 0.059833
# Iteration  93 | cost = 0.060625
# Iteration  94 | cost = 0.061389
# Iteration  95 | cost = 0.060615
# Iteration  96 | cost = 0.059833
# Iteration  97 | cost = 0.057288
# Iteration  98 | cost = 0.056578
# Iteration  99 | cost = 0.061063
# Iteration 100 | cost = 0.056112
# Iteration 101 | cost = 0.067406
# Iteration 102 | cost = 0.055131
# Iteration 103 | cost = 0.054304
# Iteration 104 | cost = 0.055402
# Iteration 105 | cost = 0.059396
# Iteration 106 | cost = 0.052984
# Iteration 107 | cost = 0.053396
# Iteration 108 | cost = 0.053910
# Iteration 109 | cost = 0.055368
# Iteration 110 | cost = 0.052309
# Iteration 111 | cost = 0.056906
# Iteration 112 | cost = 0.053082
# Iteration 113 | cost = 0.063294
# Iteration 114 | cost = 0.052232
# Iteration 115 | cost = 0.061168
# Iteration 116 | cost = 0.053956
# Iteration 117 | cost = 0.099096
# Iteration 118 | cost = 0.064100
# Iteration 119 | cost = 0.339208
# Iteration 120 | cost = 0.050620
# Iteration 121 | cost = 0.053868
# Iteration 122 | cost = 0.051824
# Iteration 123 | cost = 0.053124
# Iteration 124 | cost = 0.050620
# Iteration 125 | cost = 0.053724
# Iteration 126 | cost = 0.048297
# Iteration 127 | cost = 0.011753
# Iteration 128 | cost = 0.040474
# Iteration 129 | cost = 0.013468
# Iteration 130 | cost = 0.044651
# Iteration 131 | cost = 0.011385
# Iteration 132 | cost = 0.027401
# Iteration 133 | cost = 0.012017
# Iteration 134 | cost = 0.025564
# Iteration 135 | cost = 0.012384
# Iteration 136 | cost = 0.021811
# Iteration 137 | cost = 0.011805
# Iteration 138 | cost = 0.021512
# Iteration 139 | cost = 0.011831
# Iteration 140 | cost = 0.019422
# Iteration 141 | cost = 0.011864
# Iteration 142 | cost = 0.032515
# Iteration 143 | cost = 0.014228
# Iteration 144 | cost = 0.023846
# Iteration 145 | cost = 0.014542
# Iteration 146 | cost = 0.021939
# Iteration 147 | cost = 0.012210
# Iteration 148 | cost = 0.016892
# Iteration 149 | cost = 0.010203
# Iteration 150 | cost = 0.016322
# Précision test re-uploading : 62.00%

# %%
if USE_REUPLOAD:
    print("Circuit re-uploading appris :")
    qc_reupload = create_reupload_circuit(X_train[0], theta_re, omega_re, measure=False)
    qc_reupload.draw("mpl")
# Out:
# Circuit re-uploading appris :

# %%
if USE_REUPLOAD:
    plt.figure(figsize=(7, 4))
    plt.plot(reupload_cost_history)
    plt.xlabel("Itération")
    plt.ylabel("Cost")
    plt.title("Courbe de coût - modèle re-uploading (1 qubit)")
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
def plot_3d_reupload():
    pred1 = X_test[y_pred_reupload == 1]
    pred0 = X_test[y_pred_reupload == 0]

    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(pred0[:, 0], pred0[:, 1], pred0[:, 2], color='red', label='pred0', alpha=0.7)
    ax.scatter(pred1[:, 0], pred1[:, 1], pred1[:, 2], color='blue', label='pred1', alpha=0.7)

    ax.set_xlabel('x1')
    ax.set_ylabel('x2')
    ax.set_zlabel('x3')
    ax.set_title('Prédictions du modèle re-uploading (1 qubit)')
    ax.legend()
    plt.show()

if USE_REUPLOAD and N_DIM == 3:
    plot_3d_reupload()

# %%
if USE_REUPLOAD:
    print("=== Comparaison rapide ===")
    print(f"VQC classique  ({N_DIM} qubits) : {accuracy * 100:.2f}%")
    print(f"Re-uploading   (1 qubit)  : {reupload_accuracy * 100:.2f}%")
# Out:
# === Comparaison rapide ===
# VQC classique  (3 qubits) : 68.00%
# Re-uploading   (1 qubit)  : 62.00%
