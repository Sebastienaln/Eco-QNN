# %%
import numpy as np
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit
from qiskit.circuit.library import zz_feature_map, real_amplitudes
from qiskit_machine_learning.algorithms import VQC
from qiskit_algorithms.optimizers import L_BFGS_B
from qiskit_algorithms.optimizers import COBYLA
from qiskit_algorithms.optimizers import SPSA 
from qiskit_aer import AerSimulator
from sklearn.model_selection import train_test_split

# %%
# ── Configuration ─────────────────────────────────────────────────────────────

# Dataset
n          = 500    # Number of generated points
TEST_SIZE  = 0.2    # Fraction used for test set
SEED       = 1      # Random seed (data split & optimizer init)
N_DIM      = 3      # Features dimension

# Optimization
MAXITER    = 200     # minimizer max iterations
optimizer = COBYLA(maxiter=MAXITER) 
# ──────────────────────────────────────────────────────────────────────────────

# %%
def generate_nsphere_data(n_samples, n_dim, radius=None):
    # Génération de points entre -1 et 1
    X = np.random.uniform(-1, 1, (n_samples, n_dim))    
    # Le rayon par défaut est choisi pour équilibrer les classes
    if radius is None:
        radius = np.sqrt(n_dim / 3) 
        
    # Calcul de la norme euclidienne au carré
    dist_sq = np.sum(X**2, axis=1)
    y = (dist_sq >= radius**2).astype(int)
    
    return X, y, radius

# %%
X, y, R = generate_nsphere_data(n_samples=n, n_dim=N_DIM)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print(X_train.shape, y_train.shape)
# Out:
# (400, 3) (400,)

# %% [markdown]
# ## VQC

# %%
iteration = 0
def callback(*args):
    global iteration
    iteration += 1 
    print(f"Iteration {iteration}")

# %%
feature_map = zz_feature_map(feature_dimension=N_DIM, reps=2)
ansatz = real_amplitudes(num_qubits=N_DIM, reps=2)

vqc = VQC(feature_map=feature_map, ansatz=ansatz, optimizer=optimizer, callback=callback)
# Out:
# No gradient function provided, creating a gradient function. If your Sampler requires transpilation, please provide a pass manager.

# %% [markdown]
# ## Training

# %%
print(f"Entraînement sur une {N_DIM}-sphère...")
vqc.fit(X_train, y_train )
# Out:
# Entraînement sur une 3-sphère...

# %% [markdown]
# ## VQC Results

# %%
accuracy = vqc.score(X_test, y_test)
y_pred = vqc.predict(X_test)
print(f"Précision sur le test: {accuracy*100} %")
# Out:
# Précision sur le test: 69.0 %

# %% [markdown]
# ### VQC circuit

# %%
# 1. Visualiser comment les données N-dim sont encodées
print("--- FEATURE MAP ---")
vqc.feature_map.draw('mpl')
# Out:
# --- FEATURE MAP ---

# %%
# 2. Visualiser la structure d'entraînement (les couches de rotation et CNOT)
print("--- ANSATZ ---")
vqc.ansatz.draw('mpl')
# Out:
# --- ANSATZ ---

# %% [markdown]
# ### Visualisation si dim=2 ou 3

# %%
def plot_2d() : 
    pred1 = X_test[y_pred == 1]
    pred0 = X_test[y_pred == 0]

    plt.scatter(pred0[:,0],pred0[:,1], color = 'red', label='pred0')
    plt.scatter(pred1[:,0],pred1[:,1], color = 'blue', label='pred1')


    circle_rad = np.sqrt(N_DIM/3) # rayon par défaut, à modifier si le rayon est changé
    circle = plt.Circle((0, 0), circle_rad, color='black', fill=False, 
                        linestyle='--', linewidth=2, label='Frontière réelle')
    plt.gca().add_artist(circle)

    # Configuration du graphique
    plt.title(f"Visualisation des performances ({accuracy*100}%)")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.axhline(0, color='black', linewidth=0.5, alpha=0.5)
    plt.axvline(0, color='black', linewidth=0.5, alpha=0.5)
    plt.legend(loc='upper right')
    plt.axis('equal')
    plt.grid(True, alpha=0.3)
    plt.show()
    
def plot_3d() :
    from mpl_toolkits.mplot3d import Axes3D
 
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    
    # Masques pour séparer les résultats
    pred1 = X_test[y_pred == 1]
    pred0 = X_test[y_pred == 0]

    ax.scatter(pred0[:,0],pred0[:,1],pred0[:,2], color = 'red', label='pred0')
    ax.scatter(pred1[:,0],pred1[:,1],pred1[:,2], color = 'blue', label='pred1')
    

    # Dessiner l'enveloppe de la sphère théorique (Wireframe)
    u = np.linspace(0, 2 * np.pi, 30)
    v = np.linspace(0, np.pi, 30)
    x_sphere = R * np.outer(np.cos(u), np.sin(v))
    y_sphere = R * np.outer(np.sin(u), np.sin(v))
    z_sphere = R * np.outer(np.ones(np.size(u)), np.cos(v))
    ax.plot_wireframe(x_sphere, y_sphere, z_sphere, color="black", alpha=0.1, linewidths=0.5)

    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title(f"Visualisation 3D : Accuracy {accuracy*100}%")
    ax.legend()
    plt.show()

# %%
if N_DIM == 2 : 
    plot_2d()
    
elif N_DIM == 3 : 
    plot_3d()

# %% [markdown]
# ## Re-uploading baseline (1 qubit, seulement pour la 3-sphère)
#
# On garde le VQC actuel, puis on ajoute un second entraînement inspiré du notebook `circuit.ipynb`. Cette seconde partie n'est exécutée que si `N_DIM == 3`, car on veut tester l'idée qu'un seul qubit peut suffire avec du re-uploading.

# %%
from scipy.optimize import minimize
from qiskit_aer import StatevectorSimulator

# %%
# Hyperparamètres du modèle re-uploading
RC_REUPLOAD = 8      # nombre de couches de re-uploading
MAXITER_REUPLOAD = 150
USE_REUPLOAD = (N_DIM == 3)

print(f"USE_REUPLOAD = {USE_REUPLOAD}")
if not USE_REUPLOAD:
    print("Le bloc re-uploading ci-dessous est prévu pour N_DIM = 3.")
# Out:
# USE_REUPLOAD = True

# %%
def U_su2_reupload(qc, theta_block, omega_block, x, qubit=0):
    """
    Une couche de type U(theta + omega * x) sur un seul qubit.
    Pour N_DIM=3, on injecte directement les 3 coordonnées.
    """
    qc.u(
        theta_block[0] + omega_block[0] * x[0],
        theta_block[1] + omega_block[1] * x[1],
        theta_block[2] + omega_block[2] * x[2],
        qubit
    )

def create_reupload_circuit(x, theta, omega, measure=False):
    qc = QuantumCircuit(1)
    for r in range(RC_REUPLOAD):
        qc.h(0)
        U_su2_reupload(qc, theta[r], omega[r], x, qubit=0)
    if measure:
        qc.measure_all()
    return qc

def get_reupload_probs_batch(circuits):
    sim = StatevectorSimulator()
    probs = []
    for qc in circuits:
        sv = sim.run(qc).result().get_statevector()
        p0 = float(np.abs(sv[0])**2)
        p1 = float(np.abs(sv[1])**2)
        probs.append((p0, p1))
    return probs

# %%
def reupload_cost_weighted(params, X, y):
    """
    Même esprit que dans circuit.ipynb :
    - theta : paramètres "de traitement"
    - omega : poids qui multiplient les features avant réinjection
    - alphas : poids de classe pour équilibrer le coût
    """
    theta = params[:3 * RC_REUPLOAD].reshape(RC_REUPLOAD, 3)
    omega = params[3 * RC_REUPLOAD:6 * RC_REUPLOAD].reshape(RC_REUPLOAD, 3)
    alphas = params[6 * RC_REUPLOAD:]  # alpha_0, alpha_1

    circuits = [create_reupload_circuit(x, theta, omega, measure=False) for x in X]
    probs = get_reupload_probs_batch(circuits)

    total_cost = 0.0
    for i, y_target in enumerate(y):
        p0, p1 = probs[i]
        y_expected = (1.0, 0.0) if y_target == 0 else (0.0, 1.0)
        weight = alphas[y_target] ** 2
        total_cost += weight * ((p0 - y_expected[0])**2 + (p1 - y_expected[1])**2)

    return 0.5 * total_cost / len(X)

def unpack_reupload_params(params):
    theta = params[:3 * RC_REUPLOAD].reshape(RC_REUPLOAD, 3)
    omega = params[3 * RC_REUPLOAD:6 * RC_REUPLOAD].reshape(RC_REUPLOAD, 3)
    alphas = params[6 * RC_REUPLOAD:]
    return theta, omega, alphas

def optimize_reupload_parameters(X, y):
    rng = np.random.default_rng(SEED)
    init = rng.uniform(-np.pi, np.pi, size=6 * RC_REUPLOAD + 2)

    reupload_cost_history = []

    def objective(params):
        cost = reupload_cost_weighted(params, X, y)
        reupload_cost_history.append(cost)
        print(f"Iteration {len(reupload_cost_history):3d} | cost = {cost:.6f}")
        return cost

    res = minimize(
        objective,
        init,
        method="COBYLA",
        options={"maxiter": MAXITER_REUPLOAD}
    )

    theta_opt, omega_opt, alphas_opt = unpack_reupload_params(res.x)
    return res, theta_opt, omega_opt, alphas_opt, reupload_cost_history

def predict_reupload_batch(X, theta, omega):
    circuits = [create_reupload_circuit(x, theta, omega, measure=False) for x in X]
    probs = get_reupload_probs_batch(circuits)
    return np.array([0 if p0 >= p1 else 1 for p0, p1 in probs])

def evaluate_reupload(X, y, theta, omega):
    y_pred = predict_reupload_batch(X, theta, omega)
    accuracy = np.mean(y_pred == y)
    return accuracy, y_pred

# %%
if USE_REUPLOAD:
    print("Entraînement du modèle re-uploading (1 qubit)...")
    reupload_res, theta_re, omega_re, alpha_re, reupload_cost_history = optimize_reupload_parameters(X_train, y_train)

    reupload_accuracy, y_pred_reupload = evaluate_reupload(X_test, y_test, theta_re, omega_re)
    print(f"Précision test re-uploading : {100 * reupload_accuracy:.2f}%")
else:
    print("Bloc non exécuté car N_DIM != 3")
# Out:
# Entraînement du modèle re-uploading (1 qubit)...
# Iteration   1 | cost = 1.438174
# Iteration   2 | cost = 1.482617
# Iteration   3 | cost = 1.504826
# Iteration   4 | cost = 1.296214
# Iteration   5 | cost = 1.524173
# Iteration   6 | cost = 1.408592
# Iteration   7 | cost = 1.377298
# Iteration   8 | cost = 1.216825
# Iteration   9 | cost = 1.476445
# Iteration  10 | cost = 1.008845
# Iteration  11 | cost = 1.301449
# Iteration  12 | cost = 1.049866
# Iteration  13 | cost = 0.996455
# Iteration  14 | cost = 1.459541
# Iteration  15 | cost = 1.099654
# Iteration  16 | cost = 0.852108
# Iteration  17 | cost = 0.856374
# Iteration  18 | cost = 1.045702
# Iteration  19 | cost = 0.895501
# Iteration  20 | cost = 1.023173
# Iteration  21 | cost = 0.896130
# Iteration  22 | cost = 0.978616
# Iteration  23 | cost = 1.087944
# Iteration  24 | cost = 0.852108
# Iteration  25 | cost = 1.082412
# Iteration  26 | cost = 0.869330
# Iteration  27 | cost = 0.850141
# Iteration  28 | cost = 0.893637
# Iteration  29 | cost = 0.938943
# Iteration  30 | cost = 0.902529
# Iteration  31 | cost = 0.894880
# Iteration  32 | cost = 0.839586
# Iteration  33 | cost = 0.898515
# Iteration  34 | cost = 0.977600
# Iteration  35 | cost = 0.839909
# Iteration  36 | cost = 0.940450
# Iteration  37 | cost = 0.925959
# Iteration  38 | cost = 0.934810
# Iteration  39 | cost = 0.857472
# Iteration  40 | cost = 0.856061
# Iteration  41 | cost = 0.898191
# Iteration  42 | cost = 0.969597
# Iteration  43 | cost = 0.974302
# Iteration  44 | cost = 0.960210
# Iteration  45 | cost = 0.946431
# Iteration  46 | cost = 0.855844
# Iteration  47 | cost = 1.095049
# Iteration  48 | cost = 0.839586
# Iteration  49 | cost = 0.914292
# Iteration  50 | cost = 0.558868
# Iteration  51 | cost = 1.104178
# Iteration  52 | cost = 0.316197
# Iteration  53 | cost = 0.290095
# Iteration  54 | cost = 0.331565
# Iteration  55 | cost = 0.294831
# Iteration  56 | cost = 0.295331
# Iteration  57 | cost = 0.298000
# Iteration  58 | cost = 0.316543
# Iteration  59 | cost = 0.289800
# Iteration  60 | cost = 0.307419
# Iteration  61 | cost = 0.232516
# Iteration  62 | cost = 0.245561
# Iteration  63 | cost = 0.122179
# Iteration  64 | cost = 0.128026
# Iteration  65 | cost = 0.063699
# Iteration  66 | cost = 0.065577
# Iteration  67 | cost = 0.046663
# Iteration  68 | cost = 0.046113
# Iteration  69 | cost = 0.008700
# Iteration  70 | cost = 0.008642
# Iteration  71 | cost = 0.003969
# Iteration  72 | cost = 0.004011
# Iteration  73 | cost = 0.011310
# Iteration  74 | cost = 0.003807
# Iteration  75 | cost = 0.005286
# Iteration  76 | cost = 0.003710
# Iteration  77 | cost = 0.027376
# Iteration  78 | cost = 0.003710
# Iteration  79 | cost = 0.007588
# Iteration  80 | cost = 0.003792
# Iteration  81 | cost = 0.006774
# Iteration  82 | cost = 0.003808
# Iteration  83 | cost = 0.005761
# Iteration  84 | cost = 0.003879
# Iteration  85 | cost = 0.013837
# Iteration  86 | cost = 0.003642
# Iteration  87 | cost = 0.018741
# Iteration  88 | cost = 0.003511
# Iteration  89 | cost = 0.012671
# Iteration  90 | cost = 0.003581
# Iteration  91 | cost = 0.012848
# Iteration  92 | cost = 0.003536
# Iteration  93 | cost = 0.010192
# Iteration  94 | cost = 0.003049
# Iteration  95 | cost = 0.052071
# Iteration  96 | cost = 0.004585
# Iteration  97 | cost = 0.047347
# Iteration  98 | cost = 0.003735
# Iteration  99 | cost = 0.026536
# Iteration 100 | cost = 0.003704
# Iteration 101 | cost = 0.028571
# Iteration 102 | cost = 0.019108
# Iteration 103 | cost = 0.008123
# Iteration 104 | cost = 0.004208
# Iteration 105 | cost = 0.005329
# Iteration 106 | cost = 0.003195
# Iteration 107 | cost = 0.005346
# Iteration 108 | cost = 0.003604
# Iteration 109 | cost = 0.005489
# Iteration 110 | cost = 0.003671
# Iteration 111 | cost = 0.002891
# Iteration 112 | cost = 0.002501
# Iteration 113 | cost = 0.001320
# Iteration 114 | cost = 0.001383
# Iteration 115 | cost = 0.005895
# Iteration 116 | cost = 0.001338
# Iteration 117 | cost = 0.006165
# Iteration 118 | cost = 0.001369
# Iteration 119 | cost = 0.002132
# Iteration 120 | cost = 0.001448
# Iteration 121 | cost = 0.018427
# Iteration 122 | cost = 0.001607
# Iteration 123 | cost = 0.016153
# Iteration 124 | cost = 0.004785
# Iteration 125 | cost = 0.002185
# Iteration 126 | cost = 0.001354
# Iteration 127 | cost = 0.010490
# Iteration 128 | cost = 0.001084
# Iteration 129 | cost = 0.010399
# Iteration 130 | cost = 0.001122
# Iteration 131 | cost = 0.005863
# Iteration 132 | cost = 0.001536
# Iteration 133 | cost = 0.001101
# Iteration 134 | cost = 0.003842
# Iteration 135 | cost = 0.106989
# Iteration 136 | cost = 0.001135
# Iteration 137 | cost = 0.049945
# Iteration 138 | cost = 0.007173
# Iteration 139 | cost = 0.001093
# Iteration 140 | cost = 0.001981
# Iteration 141 | cost = 0.001135
# Iteration 142 | cost = 0.006050
# Iteration 143 | cost = 0.001106
# Iteration 144 | cost = 0.002659
# Iteration 145 | cost = 0.001131
# Iteration 146 | cost = 0.001526
# Iteration 147 | cost = 0.001084
# Iteration 148 | cost = 0.001628
# Iteration 149 | cost = 0.001093
# Iteration 150 | cost = 0.001148
# Précision test re-uploading : 60.00%

# %%
if USE_REUPLOAD:
    print("Circuit re-uploading appris :")
    qc_reupload = create_reupload_circuit(X_train[0], theta_re, omega_re, measure=False)
    qc_reupload.draw("mpl")
# Out:
# Circuit re-uploading appris :

# %%
if USE_REUPLOAD:
    plt.figure(figsize=(7, 4))
    plt.plot(reupload_cost_history)
    plt.xlabel("Itération")
    plt.ylabel("Cost")
    plt.title("Courbe de coût - modèle re-uploading (1 qubit)")
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
def plot_3d_reupload():
    pred1 = X_test[y_pred_reupload == 1]
    pred0 = X_test[y_pred_reupload == 0]

    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(pred0[:, 0], pred0[:, 1], pred0[:, 2], color='red', label='pred0', alpha=0.7)
    ax.scatter(pred1[:, 0], pred1[:, 1], pred1[:, 2], color='blue', label='pred1', alpha=0.7)

    ax.set_xlabel('x1')
    ax.set_ylabel('x2')
    ax.set_zlabel('x3')
    ax.set_title('Prédictions du modèle re-uploading (1 qubit)')
    ax.legend()
    plt.show()

if USE_REUPLOAD and N_DIM == 3:
    plot_3d_reupload()

# %% [markdown]
# ## AdaBoost sur le modèle re-uploading (1 qubit)
#
# On reprend l'idée de `circuit.ipynb` : entraîner plusieurs faibles classifieurs quantiques de façon séquentielle,
# puis agréger leurs votes avec des poids AdaBoost.
#
# Cette section n'est exécutée que si `USE_REUPLOAD` est vrai (donc pour `N_DIM == 3`).

# %%
N_ESTIMATORS_REUPLOAD = 5
MAXITER_WEAK_REUPLOAD = MAXITER_REUPLOAD

def reupload_cost_weighted_samples(params, X, y, sample_weights):
    theta = params[:3 * RC_REUPLOAD].reshape(RC_REUPLOAD, 3)
    omega = params[3 * RC_REUPLOAD:].reshape(RC_REUPLOAD, 3)

    circuits = [create_reupload_circuit(x, theta, omega, measure=False) for x in X]
    probs = get_reupload_probs_batch(circuits)

    total_cost = 0.0
    for i, y_target in enumerate(y):
        p0, p1 = probs[i]
        y_expected = (1.0, 0.0) if y_target == 0 else (0.0, 1.0)
        total_cost += sample_weights[i] * ((p0 - y_expected[0])**2 + (p1 - y_expected[1])**2)

    return 0.5 * total_cost / np.sum(sample_weights)

def optimize_reupload_weak_learner(X, y, sample_weights, seed):
    rng = np.random.default_rng(seed)
    init = rng.uniform(-np.pi, np.pi, size=6 * RC_REUPLOAD)

    res = minimize(
        reupload_cost_weighted_samples,
        init,
        args=(X, y, sample_weights),
        method="COBYLA",
        options={"maxiter": MAXITER_WEAK_REUPLOAD},
    )

    theta = res.x[:3 * RC_REUPLOAD].reshape(RC_REUPLOAD, 3)
    omega = res.x[3 * RC_REUPLOAD:].reshape(RC_REUPLOAD, 3)
    return theta, omega, res.fun

def train_adaboost_reupload(X_train, y_train, n_estimators=N_ESTIMATORS_REUPLOAD):
    n = len(y_train)
    weights = np.ones(n) / n
    estimators = []

    for i in range(n_estimators):
        theta, omega, cost = optimize_reupload_weak_learner(
            X_train, y_train, weights, seed=SEED + 100 + i
        )

        y_pred = predict_reupload_batch(X_train, theta, omega)
        incorrect = (y_pred != y_train).astype(float)
        eps = np.dot(weights, incorrect)
        eps = np.clip(eps, 1e-10, 1 - 1e-10)

        alpha = 0.5 * np.log((1 - eps) / eps)

        y_signed = np.where(y_train == 0, -1.0, 1.0)
        h_signed = np.where(y_pred == 0, -1.0, 1.0)
        weights *= np.exp(-alpha * y_signed * h_signed)
        weights /= np.sum(weights)

        estimators.append((theta, omega, alpha))
        print(f"round {i + 1:02d} | cost={cost:.4f} eps={eps:.4f} alpha={alpha:.4f}")

    return estimators

def predict_adaboost_reupload(X, estimators):
    scores = np.zeros(len(X))
    for theta, omega, alpha in estimators:
        h_signed = np.where(predict_reupload_batch(X, theta, omega) == 0, -1.0, 1.0)
        scores += alpha * h_signed
    return np.where(scores >= 0, 1, 0)

def evaluate_adaboost_reupload(X, y, estimators, positive_label=1):
    y_pred = predict_adaboost_reupload(X, estimators)
    tp = np.sum((y_pred == positive_label) & (y == positive_label))
    fp = np.sum((y_pred == positive_label) & (y != positive_label))
    fn = np.sum((y_pred != positive_label) & (y == positive_label))
    tn = np.sum((y_pred != positive_label) & (y != positive_label))

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    accuracy = np.mean(y_pred == y)
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0

    return {
        "precision": precision,
        "accuracy": accuracy,
        "recall": recall,
        "tp": int(tp),
        "fp": int(fp),
        "fn": int(fn),
        "tn": int(tn),
        "y_pred": y_pred,
    }

if USE_REUPLOAD:
    print("Entraînement AdaBoost (base learner: re-uploading 1 qubit)...")
    estimators_reupload_boost = train_adaboost_reupload(
        X_train, y_train, n_estimators=N_ESTIMATORS_REUPLOAD
    )
    metrics_reupload_boost = evaluate_adaboost_reupload(X_test, y_test, estimators_reupload_boost)
    y_pred_reupload_boost = metrics_reupload_boost["y_pred"]
    reupload_boost_accuracy = metrics_reupload_boost["accuracy"]
    print(
        f"AdaBoost re-uploading | precision={metrics_reupload_boost['precision']:.4f} "
        f"recall={metrics_reupload_boost['recall']:.4f} accuracy={reupload_boost_accuracy:.4f}"
    )
else:
    estimators_reupload_boost = None
    metrics_reupload_boost = None
    y_pred_reupload_boost = None
    reupload_boost_accuracy = None
# Out:
# Entraînement AdaBoost (base learner: re-uploading 1 qubit)...
# round 01 | cost=0.1659 eps=0.2225 alpha=0.6256
# round 02 | cost=0.1810 eps=0.2683 alpha=0.5016
# round 03 | cost=0.1895 eps=0.2717 alpha=0.4931
# round 04 | cost=0.1636 eps=0.2341 alpha=0.5928
# round 05 | cost=0.1882 eps=0.2663 alpha=0.5067
# AdaBoost re-uploading | precision=0.8302 recall=0.8980 accuracy=0.8600

# %%
if USE_REUPLOAD and N_DIM == 3:
    fig = plt.figure(figsize=(14, 6))

    ax1 = fig.add_subplot(121, projection='3d')
    ax1.scatter(
        X_test[y_pred_reupload == 0][:, 0], X_test[y_pred_reupload == 0][:, 1], X_test[y_pred_reupload == 0][:, 2],
        color='red', alpha=0.7, label='pred0'
    )
    ax1.scatter(
        X_test[y_pred_reupload == 1][:, 0], X_test[y_pred_reupload == 1][:, 1], X_test[y_pred_reupload == 1][:, 2],
        color='blue', alpha=0.7, label='pred1'
    )
    ax1.set_title(f"Re-uploading seul | acc={reupload_accuracy:.3f}")
    ax1.set_xlabel('x1')
    ax1.set_ylabel('x2')
    ax1.set_zlabel('x3')
    ax1.legend()

    ax2 = fig.add_subplot(122, projection='3d')
    ax2.scatter(
        X_test[y_pred_reupload_boost == 0][:, 0], X_test[y_pred_reupload_boost == 0][:, 1], X_test[y_pred_reupload_boost == 0][:, 2],
        color='red', alpha=0.7, label='pred0'
    )
    ax2.scatter(
        X_test[y_pred_reupload_boost == 1][:, 0], X_test[y_pred_reupload_boost == 1][:, 1], X_test[y_pred_reupload_boost == 1][:, 2],
        color='blue', alpha=0.7, label='pred1'
    )
    ax2.set_title(f"AdaBoost re-uploading | acc={reupload_boost_accuracy:.3f}")
    ax2.set_xlabel('x1')
    ax2.set_ylabel('x2')
    ax2.set_zlabel('x3')
    ax2.legend()

    plt.tight_layout()
    plt.show()

# %%
if USE_REUPLOAD:
    print("=== Comparaison finale ===")
    print(f"VQC classique            ({N_DIM} qubits) : {accuracy * 100:.2f}%")
    print(f"Re-uploading             (1 qubit)  : {reupload_accuracy * 100:.2f}%")
    print(f"AdaBoost + re-uploading  (1 qubit)  : {reupload_boost_accuracy * 100:.2f}%")

    gain = (reupload_boost_accuracy - reupload_accuracy) * 100
    print(f"Gain AdaBoost vs re-uploading seul : {gain:+.2f} points")
# Out:
# === Comparaison finale ===
# VQC classique            (3 qubits) : 69.00%
# Re-uploading             (1 qubit)  : 60.00%
# AdaBoost + re-uploading  (1 qubit)  : 86.00%
# Gain AdaBoost vs re-uploading seul : +26.00 points
