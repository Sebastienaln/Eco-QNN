# %%
import numpy as np
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit, transpile
from qiskit.circuit.library import zz_feature_map, real_amplitudes
from qiskit_machine_learning.algorithms import VQC
from qiskit_algorithms.optimizers import L_BFGS_B
from qiskit_algorithms.optimizers import COBYLA
from qiskit_algorithms.optimizers import SPSA 
from qiskit_aer import AerSimulator
from sklearn.model_selection import train_test_split

from qiskit_aer import AerSimulator
from qiskit_aer.noise import NoiseModel, depolarizing_error
from qiskit_ibm_runtime import SamplerV2 as Sampler

# %%
# ── Configuration ─────────────────────────────────────────────────────────────

# Dataset
n          = 1000    # Number of generated points
TEST_SIZE  = 0.2    # Fraction used for test set
SEED       = 1      # Random seed (data split & optimizer init)
N_DIM      = 6     # Features dimension

# Optimization
MAXITER    = 1000     # minimizer max iterations
optimizer = COBYLA(maxiter=MAXITER) 

# Noise 
USE_NOISE = False 
NOISE_RATE = 0.02
# ──────────────────────────────────────────────────────────────────────────────
REUPLOAD_SHOTS = 2048

# %%
if USE_NOISE:
    print("Construction du simulateur BRUITÉ...")
    nm = NoiseModel()
    # Erreur sur les portes simples (1 qubit)
    err1 = depolarizing_error(NOISE_RATE, 1)
    nm.add_all_qubit_quantum_error(err1, ['u', 'h', 'ry', 'rz'])
    # Erreur sur l'intrication (2 qubits) - on met souvent 5x plus
    err2 = depolarizing_error(NOISE_RATE * 5, 2)
    nm.add_all_qubit_quantum_error(err2, ['cx'])
    
    # On crée le backend (ton ancien AerSimulator)
    backend = AerSimulator(noise_model=nm, method="density_matrix")
    # On l'enveloppe pour le rendre compatible VQC
    sampler = Sampler(backend)
else:
    print("-> Mode IDÉAL")
    sampler = Sampler(AerSimulator())
# Out:
# -> Mode IDÉAL

# %%
def generate_nsphere_data(n_samples, n_dim, radius=None):
    # Génération de points entre -1 et 1
    X = np.random.uniform(-1, 1, (n_samples, n_dim))    
    # Le rayon par défaut est choisi pour équilibrer les classes
    if radius is None:
        radius = np.sqrt(n_dim / 3) 
        
    # Calcul de la norme euclidienne au carré
    dist_sq = np.sum(X**2, axis=1)
    y = (dist_sq >= radius**2).astype(int)
    
    return X, y, radius

# %%
X, y, R = generate_nsphere_data(n_samples=n, n_dim=N_DIM)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print(X_train.shape, y_train.shape)
# Out:
# (800, 3) (800,)

# %% [markdown]
# ## Re-uploading baseline (1 qubit, seulement pour la 3-sphère)
#
# On garde le VQC actuel, puis on ajoute un second entraînement inspiré du notebook `circuit.ipynb`. Cette seconde partie n'est exécutée que si `N_DIM == 3`, car on veut tester l'idée qu'un seul qubit peut suffire avec du re-uploading.

# %%
from scipy.optimize import minimize
from qiskit_aer import StatevectorSimulator

# %%
# Hyperparamètres du modèle re-uploading
RC_REUPLOAD_VALUES = [2, 4, 6, 8, 10, 12, 14]
MAXITER_REUPLOAD = 150
USE_REUPLOAD = (N_DIM == 3)

print(f"USE_REUPLOAD = {USE_REUPLOAD}")
print(f"RC_REUPLOAD_VALUES = {RC_REUPLOAD_VALUES}")
if not USE_REUPLOAD:
    print("Le bloc re-uploading ci-dessous est prévu pour N_DIM = 3.")
# Out:
# USE_REUPLOAD = True
# RC_REUPLOAD_VALUES = [2, 4, 6, 8, 10, 12, 14]

# %%
def U_su2_reupload(qc, theta_block, omega_block, x, qubit=0):
    """
    Une couche de type U(theta + omega * x) sur un seul qubit.
    Pour N_DIM=3, on injecte directement les 3 coordonnées.
    """
    qc.u(
        theta_block[0] + omega_block[0] * x[0],
        theta_block[1] + omega_block[1] * x[1],
        theta_block[2] + omega_block[2] * x[2],
        qubit
    )

def create_reupload_circuit(x, theta, omega, rc_reupload, measure=False):
    qc = QuantumCircuit(1)
    for r in range(rc_reupload):
        qc.h(0)
        U_su2_reupload(qc, theta[r], omega[r], x, qubit=0)
    if measure:
        qc.measure_all()
    return qc

def get_reupload_probs_batch(circuits, shots=REUPLOAD_SHOTS):
    """
    - Si USE_NOISE = True : exécute les circuits mesurés sur AerSimulator bruité.
    - Sinon : utilise StatevectorSimulator pour obtenir les probabilités exactes.
    """
    probs = []

    if USE_NOISE:
        measured_circuits = []
        for qc in circuits:
            qc_m = qc.copy()
            if qc_m.num_clbits == 0:
                qc_m.measure_all()
            measured_circuits.append(qc_m)

        transpiled_circuits = transpile(measured_circuits, backend)
        result = backend.run(transpiled_circuits, shots=shots).result()

        for qc_t in transpiled_circuits:
            counts = result.get_counts(qc_t)
            p0 = counts.get('0', 0) / shots
            p1 = counts.get('1', 0) / shots
            probs.append((p0, p1))
    else:
        sim = StatevectorSimulator()
        for qc in circuits:
            sv = sim.run(qc).result().get_statevector()
            p0 = float(np.abs(sv[0])**2)
            p1 = float(np.abs(sv[1])**2)
            probs.append((p0, p1))

    return probs

def reupload_cost_weighted(params, X, y, rc_reupload):
    """
    Même esprit que dans circuit.ipynb :
    - theta : paramètres "de traitement"
    - omega : poids qui multiplient les features avant réinjection
    - alphas : poids de classe pour équilibrer le coût
    """
    theta = params[:3 * rc_reupload].reshape(rc_reupload, 3)
    omega = params[3 * rc_reupload:6 * rc_reupload].reshape(rc_reupload, 3)
    alphas = params[6 * rc_reupload:]  # alpha_0, alpha_1

    circuits = [create_reupload_circuit(x, theta, omega, rc_reupload, measure=False) for x in X]
    probs = get_reupload_probs_batch(circuits)

    total_cost = 0.0
    for i, y_target in enumerate(y):
        p0, p1 = probs[i]
        y_expected = (1.0, 0.0) if y_target == 0 else (0.0, 1.0)
        weight = alphas[y_target] ** 2
        total_cost += weight * ((p0 - y_expected[0])**2 + (p1 - y_expected[1])**2)

    return 0.5 * total_cost / len(X)

def unpack_reupload_params(params, rc_reupload):
    theta = params[:3 * rc_reupload].reshape(rc_reupload, 3)
    omega = params[3 * rc_reupload:6 * rc_reupload].reshape(rc_reupload, 3)
    alphas = params[6 * rc_reupload:]
    return theta, omega, alphas

def optimize_reupload_parameters(X, y, rc_reupload):
    rng = np.random.default_rng(SEED)
    init = rng.uniform(-np.pi, np.pi, size=6 * rc_reupload + 2)

    reupload_cost_history = []

    def objective(params):
        cost = reupload_cost_weighted(params, X, y, rc_reupload)
        reupload_cost_history.append(cost)
        print(f"[RC={rc_reupload}] Iteration {len(reupload_cost_history):3d} | cost = {cost:.6f}")
        return cost

    res = minimize(
        objective,
        init,
        method="COBYLA",
        options={"maxiter": MAXITER_REUPLOAD}
    )

    theta_opt, omega_opt, alphas_opt = unpack_reupload_params(res.x, rc_reupload)
    return res, theta_opt, omega_opt, alphas_opt, reupload_cost_history

def predict_reupload_batch(X, theta, omega, rc_reupload):
    circuits = [create_reupload_circuit(x, theta, omega, rc_reupload, measure=False) for x in X]
    probs = get_reupload_probs_batch(circuits)
    return np.array([0 if p0 >= p1 else 1 for p0, p1 in probs])

def evaluate_reupload(X, y, theta, omega, rc_reupload):
    y_pred = predict_reupload_batch(X, theta, omega, rc_reupload)
    accuracy = np.mean(y_pred == y)
    return accuracy, y_pred

# %%
# Cette cellule est volontairement laissée vide.
# Les fonctions re-uploading paramétrées par rc_reupload sont définies dans la cellule précédente.
print("Fonctions re-uploading déjà définies (version paramétrée par RC_REUPLOAD).")
# Out:
# Fonctions re-uploading déjà définies (version paramétrée par RC_REUPLOAD).

# %%
if USE_REUPLOAD:
    print("Balayage re-uploading (1 qubit) selon RC_REUPLOAD...")

    reupload_results = {
        "rc_values": [],
        "accuracies": [],
        "models": [],
        "cost_histories": []
    }

    for rc in RC_REUPLOAD_VALUES:
        print(f"\n=== Entraînement re-uploading avec RC_REUPLOAD={rc} ===")
        reupload_res, theta_re, omega_re, alpha_re, reupload_cost_history = optimize_reupload_parameters(X_train, y_train, rc)
        reupload_accuracy, y_pred_reupload = evaluate_reupload(X_test, y_test, theta_re, omega_re, rc)

        reupload_results["rc_values"].append(rc)
        reupload_results["accuracies"].append(float(reupload_accuracy))
        reupload_results["models"].append((theta_re, omega_re, alpha_re, reupload_res))
        reupload_results["cost_histories"].append(reupload_cost_history)

        print(f"Précision test re-uploading (RC={rc}) : {100 * reupload_accuracy:.2f}%")

    best_idx = int(np.argmax(reupload_results["accuracies"]))
    best_rc = reupload_results["rc_values"][best_idx]
    theta_re, omega_re, alpha_re, reupload_res = reupload_results["models"][best_idx]
    reupload_cost_history = reupload_results["cost_histories"][best_idx]
    reupload_accuracy = reupload_results["accuracies"][best_idx]
    y_pred_reupload = predict_reupload_batch(X_test, theta_re, omega_re, best_rc)

    print(f"\nMeilleur RC_REUPLOAD = {best_rc}")
    print(f"Meilleure précision test re-uploading : {100 * reupload_accuracy:.2f}%")
else:
    print("Bloc non exécuté car N_DIM != 3")
# Out:
# Balayage re-uploading (1 qubit) selon RC_REUPLOAD...
#
# === Entraînement re-uploading avec RC_REUPLOAD=2 ===
# [RC=2] Iteration   1 | cost = 0.576268
# [RC=2] Iteration   2 | cost = 0.554972
# [RC=2] Iteration   3 | cost = 0.376483
# [RC=2] Iteration   4 | cost = 0.543119
# [RC=2] Iteration   5 | cost = 0.509144
# [RC=2] Iteration   6 | cost = 0.376483
# [RC=2] Iteration   7 | cost = 0.528664
# [RC=2] Iteration   8 | cost = 0.376065
# [RC=2] Iteration   9 | cost = 0.382776
# [RC=2] Iteration  10 | cost = 0.509299
# [RC=2] Iteration  11 | cost = 0.457277
# [RC=2] Iteration  12 | cost = 0.376065
# [RC=2] Iteration  13 | cost = 0.420132
# [RC=2] Iteration  14 | cost = 0.121756
# [RC=2] Iteration  15 | cost = 0.291666
# [RC=2] Iteration  16 | cost = 0.113555
# [RC=2] Iteration  17 | cost = 0.122920
# [RC=2] Iteration  18 | cost = 0.217991
# [RC=2] Iteration  19 | cost = 0.110563
# [RC=2] Iteration  20 | cost = 0.236362
# [RC=2] Iteration  21 | cost = 0.110563
# [RC=2] Iteration  22 | cost = 0.222535
# [RC=2] Iteration  23 | cost = 0.116825
# [RC=2] Iteration  24 | cost = 0.232441
# [RC=2] Iteration  25 | cost = 0.133458
# [RC=2] Iteration  26 | cost = 0.155318
# [RC=2] Iteration  27 | cost = 0.114449
# [RC=2] Iteration  28 | cost = 0.035146
# [RC=2] Iteration  29 | cost = 0.037756
# [RC=2] Iteration  30 | cost = 0.315199
# [RC=2] Iteration  31 | cost = 0.058449
# [RC=2] Iteration  32 | cost = 0.062389
# [RC=2] Iteration  33 | cost = 0.019126
# [RC=2] Iteration  34 | cost = 0.037706
# [RC=2] Iteration  35 | cost = 0.021194
# [RC=2] Iteration  36 | cost = 0.017425
# [RC=2] Iteration  37 | cost = 0.016715
# [RC=2] Iteration  38 | cost = 0.016420
# [RC=2] Iteration  39 | cost = 0.019057
# [RC=2] Iteration  40 | cost = 0.016823
# [RC=2] Iteration  41 | cost = 0.012701
# [RC=2] Iteration  42 | cost = 0.013299
# [RC=2] Iteration  43 | cost = 0.011706
# [RC=2] Iteration  44 | cost = 0.015074
# [RC=2] Iteration  45 | cost = 0.022890
# [RC=2] Iteration  46 | cost = 0.032551
# [RC=2] Iteration  47 | cost = 0.010129
# [RC=2] Iteration  48 | cost = 0.017547
# [RC=2] Iteration  49 | cost = 0.039192
# [RC=2] Iteration  50 | cost = 0.009426
# [RC=2] Iteration  51 | cost = 0.002945
# [RC=2] Iteration  52 | cost = 0.001700
# [RC=2] Iteration  53 | cost = 0.003577
# [RC=2] Iteration  54 | cost = 0.018413
# [RC=2] Iteration  55 | cost = 0.004369
# [RC=2] Iteration  56 | cost = 0.002127
# [RC=2] Iteration  57 | cost = 0.064984
# [RC=2] Iteration  58 | cost = 0.001357
# [RC=2] Iteration  59 | cost = 0.008971
# [RC=2] Iteration  60 | cost = 0.002078
# [RC=2] Iteration  61 | cost = 0.005004
# [RC=2] Iteration  62 | cost = 0.007917
# [RC=2] Iteration  63 | cost = 0.018868
# [RC=2] Iteration  64 | cost = 0.002510
# [RC=2] Iteration  65 | cost = 0.001388
# [RC=2] Iteration  66 | cost = 0.005059
# [RC=2] Iteration  67 | cost = 0.001392
# [RC=2] Iteration  68 | cost = 0.003627
# [RC=2] Iteration  69 | cost = 0.001517
# [RC=6] Iteration  17 | cost = 1.442428
# [RC=6] Iteration  18 | cost = 0.917912
# [RC=6] Iteration  19 | cost = 1.032824
# [RC=6] Iteration  20 | cost = 0.949634
# [RC=6] Iteration  21 | cost = 0.947333
# [RC=6] Iteration  22 | cost = 0.951544
# [RC=6] Iteration  23 | cost = 0.960977
# [RC=6] Iteration  24 | cost = 0.816129
# [RC=6] Iteration  25 | cost = 0.738877
# [RC=6] Iteration  26 | cost = 0.773616
# [RC=6] Iteration  27 | cost = 0.860155
# [RC=6] Iteration  28 | cost = 0.904155
# [RC=6] Iteration  29 | cost = 0.653007
# [RC=6] Iteration  30 | cost = 0.772018
# [RC=6] Iteration  31 | cost = 0.747513
# [RC=6] Iteration  32 | cost = 0.698661
# [RC=6] Iteration  33 | cost = 0.692363
# [RC=6] Iteration  34 | cost = 0.751328
# [RC=6] Iteration  35 | cost = 0.804646
# [RC=6] Iteration  36 | cost = 0.653007
# [RC=6] Iteration  37 | cost = 0.755325
# [RC=6] Iteration  38 | cost = 0.282579
# [RC=6] Iteration  39 | cost = 0.504038
# [RC=6] Iteration  40 | cost = 0.161417
# [RC=6] Iteration  41 | cost = 0.164476
# [RC=6] Iteration  42 | cost = 0.179642
# [RC=6] Iteration  43 | cost = 0.161365
# [RC=6] Iteration  44 | cost = 0.221231
# [RC=6] Iteration  45 | cost = 0.161639
# [RC=6] Iteration  46 | cost = 0.155889
# [RC=6] Iteration  47 | cost = 0.194882
# [RC=6] Iteration  48 | cost = 0.175632
# [RC=6] Iteration  49 | cost = 0.119135
# [RC=6] Iteration  50 | cost = 0.134342
# [RC=6] Iteration  51 | cost = 0.129617
# [RC=6] Iteration  52 | cost = 0.127198
# [RC=6] Iteration  53 | cost = 0.109455
# [RC=6] Iteration  54 | cost = 0.120913
# [RC=6] Iteration  55 | cost = 0.101638
# [RC=6] Iteration  56 | cost = 0.100868
# [RC=6] Iteration  57 | cost = 0.100551
# [RC=6] Iteration  58 | cost = 0.101205
# [RC=6] Iteration  59 | cost = 0.106472
# [RC=6] Iteration  60 | cost = 0.098117
# [RC=6] Iteration  61 | cost = 0.099432
# [RC=6] Iteration  62 | cost = 0.098117
# [RC=6] Iteration  63 | cost = 0.107608
# [RC=6] Iteration  64 | cost = 0.095234
# [RC=6] Iteration  65 | cost = 0.108387
# [RC=6] Iteration  66 | cost = 0.096857
# [RC=6] Iteration  67 | cost = 0.092720
# [RC=6] Iteration  68 | cost = 0.090586
# [RC=6] Iteration  69 | cost = 0.125849
# [RC=6] Iteration  70 | cost = 0.088231
# [RC=6] Iteration  71 | cost = 0.101776
# [RC=6] Iteration  72 | cost = 0.090400
# [RC=6] Iteration  73 | cost = 0.110925
# [RC=6] Iteration  74 | cost = 0.089887
# [RC=6] Iteration  75 | cost = 0.092575
# [RC=6] Iteration  76 | cost = 0.088231
# [RC=6] Iteration  77 | cost = 0.352760
# [RC=6] Iteration  78 | cost = 0.048700
# [RC=6] Iteration  79 | cost = 0.012743
# [RC=6] Iteration 143 | cost = 0.002097
# [RC=6] Iteration 144 | cost = 0.001067
# [RC=6] Iteration 145 | cost = 0.001242
# [RC=6] Iteration 146 | cost = 0.000276
# [RC=6] Iteration 147 | cost = 0.000236
# [RC=6] Iteration 148 | cost = 0.000225
# [RC=6] Iteration 149 | cost = 0.000197
# [RC=6] Iteration 150 | cost = 0.000157
# Précision test re-uploading (RC=6) : 48.00%
#
# === Entraînement re-uploading avec RC_REUPLOAD=8 ===
# [RC=8] Iteration   1 | cost = 1.591249
# [RC=8] Iteration   2 | cost = 1.631829
# [RC=8] Iteration   3 | cost = 1.576204
# [RC=8] Iteration   4 | cost = 1.460824
# [RC=8] Iteration   5 | cost = 1.352766
# [RC=8] Iteration   6 | cost = 1.329431
# [RC=8] Iteration   7 | cost = 1.344705
# [RC=8] Iteration   8 | cost = 1.182196
# [RC=8] Iteration   9 | cost = 1.354043
# [RC=8] Iteration  10 | cost = 1.134381
# [RC=8] Iteration  11 | cost = 1.255088
# [RC=8] Iteration  12 | cost = 1.173511
# [RC=8] Iteration  13 | cost = 1.245284
# [RC=8] Iteration  14 | cost = 1.369685
# [RC=8] Iteration  15 | cost = 1.232002
# [RC=8] Iteration  16 | cost = 1.175844
# [RC=8] Iteration  17 | cost = 1.140850
# [RC=8] Iteration  18 | cost = 1.216889
# [RC=8] Iteration  19 | cost = 1.190898
# [RC=8] Iteration  20 | cost = 1.171489
# [RC=8] Iteration  21 | cost = 1.074987
# [RC=8] Iteration  22 | cost = 1.546413
# [RC=8] Iteration  23 | cost = 1.438851
# [RC=8] Iteration  24 | cost = 1.074987
# [RC=8] Iteration  25 | cost = 0.917142
# [RC=8] Iteration  26 | cost = 0.924618
# [RC=8] Iteration  27 | cost = 0.969195
# [RC=8] Iteration  28 | cost = 0.938233
# [RC=8] Iteration  29 | cost = 0.990076
# [RC=8] Iteration  30 | cost = 0.924004
# [RC=8] Iteration  31 | cost = 1.062723
# [RC=8] Iteration  32 | cost = 0.951847
# [RC=8] Iteration  33 | cost = 0.915776
# [RC=8] Iteration  34 | cost = 0.907816
# [RC=8] Iteration  35 | cost = 0.992351
# [RC=8] Iteration  36 | cost = 1.013394
# [RC=8] Iteration  37 | cost = 1.058554
# [RC=8] Iteration  38 | cost = 0.954374
# [RC=8] Iteration  39 | cost = 0.925715
# [RC=8] Iteration  40 | cost = 0.899082
# [RC=8] Iteration  41 | cost = 1.007598
# [RC=8] Iteration  42 | cost = 0.994992
# [RC=8] Iteration  43 | cost = 0.892002
# [RC=8] Iteration  44 | cost = 0.996967
# [RC=8] Iteration  45 | cost = 0.915153
# [RC=8] Iteration  46 | cost = 1.001561
# [RC=8] Iteration  47 | cost = 1.003997
# [RC=8] Iteration  48 | cost = 0.892002
# [RC=8] Iteration  49 | cost = 0.858414
# [RC=8] Iteration  50 | cost = 0.538158
# [RC=8] Iteration  51 | cost = 1.036605
# [RC=8] Iteration  52 | cost = 0.330719
# [RC=8] Iteration  53 | cost = 0.223582
# [RC=8] Iteration  54 | cost = 0.217435
# [RC=8] Iteration  55 | cost = 0.165849
# [RC=8] Iteration  56 | cost = 0.166578
# [RC=8] Iteration  57 | cost = 0.145939
# [RC=8] Iteration  58 | cost = 0.153288
# [RC=8] Iteration  59 | cost = 0.140411
# [RC=8] Iteration  60 | cost = 0.151999
# [RC=8] Iteration  61 | cost = 0.100127
# [RC=8] Iteration  62 | cost = 0.104195
# [RC=8] Iteration  63 | cost = 0.047199
# [RC=8] Iteration  64 | cost = 0.046155
# [RC=8] Iteration  65 | cost = 0.001150
# [RC=8] Iteration  66 | cost = 0.001032
# [RC=8] Iteration  67 | cost = 0.003498
# [RC=8] Iteration  68 | cost = 0.001035
# [RC=8] Iteration  69 | cost = 0.001024
# [RC=8] Iteration  70 | cost = 0.001018
# [RC=8] Iteration  71 | cost = 0.003118
# [RC=8] Iteration  72 | cost = 0.001083
# [RC=8] Iteration  73 | cost = 0.002086
# [RC=8] Iteration  74 | cost = 0.001018
# [RC=8] Iteration  75 | cost = 0.003646
# [RC=8] Iteration  76 | cost = 0.001052
# [RC=8] Iteration  77 | cost = 0.022151
# [RC=8] Iteration  78 | cost = 0.000984
# [RC=8] Iteration  79 | cost = 0.006096
# [RC=8] Iteration  80 | cost = 0.001023
# [RC=8] Iteration  81 | cost = 0.002654
# [RC=8] Iteration  82 | cost = 0.001015
# [RC=8] Iteration  83 | cost = 0.014580
# [RC=8] Iteration  84 | cost = 0.000994
# [RC=8] Iteration  85 | cost = 0.008538
# [RC=8] Iteration  86 | cost = 0.001013
# [RC=8] Iteration  87 | cost = 0.006237
# [RC=8] Iteration  88 | cost = 0.000970
# [RC=8] Iteration  89 | cost = 0.003406
# [RC=8] Iteration  90 | cost = 0.001000
# [RC=8] Iteration  91 | cost = 0.008635
# [RC=8] Iteration  92 | cost = 0.000954
# [RC=8] Iteration  93 | cost = 0.008677
# [RC=8] Iteration  94 | cost = 0.000940
# [RC=8] Iteration  95 | cost = 0.017115
# [RC=8] Iteration  96 | cost = 0.001058
# [RC=8] Iteration  97 | cost = 0.010676
# [RC=8] Iteration  98 | cost = 0.000912
# [RC=8] Iteration  99 | cost = 0.119136
# [RC=8] Iteration 100 | cost = 0.000912
# [RC=8] Iteration 101 | cost = 0.028865
# [RC=8] Iteration 102 | cost = 0.007403
# [RC=8] Iteration 103 | cost = 0.023481
# [RC=8] Iteration 104 | cost = 0.000712
# [RC=8] Iteration 105 | cost = 0.004703
# [RC=8] Iteration 106 | cost = 0.000897
# [RC=8] Iteration 107 | cost = 0.000935
# [RC=8] Iteration 108 | cost = 0.000681
# [RC=8] Iteration 109 | cost = 0.000958
# [RC=8] Iteration 110 | cost = 0.001013
# [RC=8] Iteration 111 | cost = 0.000106
# [RC=8] Iteration 112 | cost = 0.000219
# [RC=8] Iteration 113 | cost = 0.002273
# [RC=8] Iteration 114 | cost = 0.000129
# [RC=8] Iteration 115 | cost = 0.014143
# [RC=8] Iteration 116 | cost = 0.002456
# [RC=8] Iteration 117 | cost = 0.047985
# [RC=8] Iteration 118 | cost = 0.000102
# [RC=8] Iteration 119 | cost = 0.014369
# [RC=8] Iteration 120 | cost = 0.000108
# [RC=8] Iteration 121 | cost = 0.008723
# [RC=8] Iteration 122 | cost = 0.000408
# [RC=8] Iteration 123 | cost = 0.004603
# [RC=8] Iteration 124 | cost = 0.000351
# [RC=8] Iteration 125 | cost = 0.039108
# [RC=8] Iteration 126 | cost = 0.000990
# [RC=8] Iteration 127 | cost = 0.001449
# [RC=8] Iteration 128 | cost = 0.002369
# [RC=8] Iteration 129 | cost = 0.005454
# [RC=8] Iteration 130 | cost = 0.003489
# [RC=8] Iteration 131 | cost = 0.005825
# [RC=8] Iteration 132 | cost = 0.000950
# [RC=8] Iteration 133 | cost = 0.100254
# [RC=8] Iteration 134 | cost = 0.000288
# [RC=8] Iteration 135 | cost = 0.015746
# [RC=8] Iteration 136 | cost = 0.000198
# [RC=8] Iteration 137 | cost = 0.013905
# [RC=8] Iteration 138 | cost = 0.000588
# [RC=8] Iteration 139 | cost = 0.000119
# [RC=8] Iteration 140 | cost = 0.000279
# [RC=8] Iteration 141 | cost = 0.000122
# [RC=8] Iteration 142 | cost = 0.000768
# [RC=8] Iteration 143 | cost = 0.000100
# [RC=8] Iteration 144 | cost = 0.000237
# [RC=8] Iteration 145 | cost = 0.000101
# [RC=8] Iteration 146 | cost = 0.001472
# [RC=8] Iteration 147 | cost = 0.000099
# [RC=8] Iteration 148 | cost = 0.000011
# [RC=8] Iteration 149 | cost = 0.000012
# [RC=8] Iteration 150 | cost = 0.000214
# Précision test re-uploading (RC=8) : 63.50%
#
# === Entraînement re-uploading avec RC_REUPLOAD=10 ===
# [RC=10] Iteration   1 | cost = 1.535219
# [RC=10] Iteration   2 | cost = 1.727487
# [RC=10] Iteration   3 | cost = 1.497419
# [RC=10] Iteration   4 | cost = 1.795113
# [RC=10] Iteration   5 | cost = 1.655072
# [RC=10] Iteration   6 | cost = 1.648293
# [RC=10] Iteration   7 | cost = 1.555135
# [RC=10] Iteration   8 | cost = 1.594996
# [RC=10] Iteration   9 | cost = 1.756365
# [RC=10] Iteration  10 | cost = 1.655893
# [RC=10] Iteration  11 | cost = 1.559855
# [RC=10] Iteration  12 | cost = 1.654749
# [RC=10] Iteration  13 | cost = 1.586017
# [RC=10] Iteration  14 | cost = 1.482304
# [RC=10] Iteration  15 | cost = 1.615620
# [RC=10] Iteration  16 | cost = 1.614934
# [RC=10] Iteration  17 | cost = 1.476994
# [RC=10] Iteration  18 | cost = 1.825273
# [RC=10] Iteration  19 | cost = 1.763421
# [RC=10] Iteration  20 | cost = 1.750853
# [RC=10] Iteration  21 | cost = 1.771773
# [RC=10] Iteration  22 | cost = 1.626770
# [RC=10] Iteration  23 | cost = 1.597684
# [RC=10] Iteration  24 | cost = 1.581240
# [RC=10] Iteration  25 | cost = 1.668433
# [RC=10] Iteration  26 | cost = 1.510954
# [RC=10] Iteration  27 | cost = 1.719739
# [RC=10] Iteration  28 | cost = 1.603696
# [RC=10] Iteration  29 | cost = 1.803420
# [RC=10] Iteration  30 | cost = 1.476994
# [RC=10] Iteration  31 | cost = 1.553166
# [RC=10] Iteration  32 | cost = 1.551505
# [RC=10] Iteration  33 | cost = 1.492654
# [RC=10] Iteration  34 | cost = 1.447237
# [RC=10] Iteration  35 | cost = 1.561731
# [RC=10] Iteration  36 | cost = 1.537878
# [RC=10] Iteration  37 | cost = 1.538906
# [RC=10] Iteration  38 | cost = 1.612360
# [RC=10] Iteration  39 | cost = 1.549870
# [RC=10] Iteration  40 | cost = 1.529012
# [RC=10] Iteration  41 | cost = 1.489146
# [RC=10] Iteration  42 | cost = 1.599314
# [RC=10] Iteration  43 | cost = 1.487358
# [RC=10] Iteration  44 | cost = 1.521752
# [RC=10] Iteration  45 | cost = 1.452360
# [RC=10] Iteration  46 | cost = 1.540792
# [RC=10] Iteration  47 | cost = 1.404518
# [RC=10] Iteration  48 | cost = 1.525911
# [RC=10] Iteration  49 | cost = 1.482397
# [RC=10] Iteration  50 | cost = 1.515343
# [RC=10] Iteration  51 | cost = 1.537424
# [RC=10] Iteration  52 | cost = 1.374665
# [RC=10] Iteration  53 | cost = 1.436696
# [RC=10] Iteration  54 | cost = 1.450974
# [RC=10] Iteration  55 | cost = 1.441602
# [RC=10] Iteration  56 | cost = 1.411991
# [RC=10] Iteration  57 | cost = 1.452749
# [RC=10] Iteration  58 | cost = 1.447467
# [RC=10] Iteration  59 | cost = 1.431839
# [RC=10] Iteration  60 | cost = 1.374665
# [RC=10] Iteration  61 | cost = 1.449477
# [RC=10] Iteration  62 | cost = 1.082012
# [RC=10] Iteration  63 | cost = 0.511255
# [RC=10] Iteration  64 | cost = 0.281016
# [RC=10] Iteration  65 | cost = 0.231511
# [RC=10] Iteration  66 | cost = 0.251596
# [RC=10] Iteration  67 | cost = 0.221921
# [RC=10] Iteration  68 | cost = 0.229458
# [RC=10] Iteration  69 | cost = 0.218956
# [RC=10] Iteration  70 | cost = 0.216702
# [RC=10] Iteration  71 | cost = 0.193388
# [RC=10] Iteration  72 | cost = 0.194150
# [RC=10] Iteration  73 | cost = 0.184714
# [RC=10] Iteration  74 | cost = 0.198951
# [RC=10] Iteration  75 | cost = 0.176166
# [RC=10] Iteration  76 | cost = 0.171468
# [RC=10] Iteration  77 | cost = 0.176968
# [RC=10] Iteration  78 | cost = 0.164565
# [RC=10] Iteration  79 | cost = 0.153400
# [RC=10] Iteration  80 | cost = 0.160680
# [RC=10] Iteration  81 | cost = 0.085391
# [RC=10] Iteration  82 | cost = 0.084948
# [RC=10] Iteration  83 | cost = 0.070214
# [RC=10] Iteration  84 | cost = 0.068665
# [RC=10] Iteration  85 | cost = 0.091251
# [RC=10] Iteration  86 | cost = 0.071590
# [RC=10] Iteration  87 | cost = 0.068894
# [RC=10] Iteration  88 | cost = 0.066418
# [RC=10] Iteration  89 | cost = 0.084045
# [RC=10] Iteration  90 | cost = 0.068622
# [RC=14] Iteration  38 | cost = 1.806492
# [RC=14] Iteration  39 | cost = 1.615478
# [RC=14] Iteration  40 | cost = 1.736670
# [RC=14] Iteration  41 | cost = 1.851042
# [RC=14] Iteration  42 | cost = 1.615478
# [RC=14] Iteration  43 | cost = 1.733905
# [RC=14] Iteration  44 | cost = 1.686840
# [RC=14] Iteration  45 | cost = 1.672697
# [RC=14] Iteration  46 | cost = 1.694558
# [RC=14] Iteration  47 | cost = 1.594230
# [RC=14] Iteration  48 | cost = 1.660079
# [RC=14] Iteration  49 | cost = 1.662980
# [RC=14] Iteration  50 | cost = 1.683552
# [RC=14] Iteration  51 | cost = 1.618685
# [RC=14] Iteration  52 | cost = 1.525982
# [RC=14] Iteration  53 | cost = 1.640971
# [RC=14] Iteration  54 | cost = 1.589407
# [RC=14] Iteration  55 | cost = 1.652462
# [RC=14] Iteration  56 | cost = 1.587403
# [RC=14] Iteration  57 | cost = 1.558323
# [RC=14] Iteration  58 | cost = 1.609271
# [RC=14] Iteration  59 | cost = 1.628592
# [RC=14] Iteration  60 | cost = 1.479505
# [RC=14] Iteration  61 | cost = 1.559737
# [RC=14] Iteration  62 | cost = 1.533821
# [RC=14] Iteration  63 | cost = 1.566871
# [RC=14] Iteration  64 | cost = 1.623616
# [RC=14] Iteration  65 | cost = 1.578674
# [RC=14] Iteration  66 | cost = 1.517000
# [RC=14] Iteration  67 | cost = 1.569938
# [RC=14] Iteration  68 | cost = 1.540087
# [RC=14] Iteration  69 | cost = 1.538324
# [RC=14] Iteration  70 | cost = 1.490118
# [RC=14] Iteration  71 | cost = 1.536073
# [RC=14] Iteration  72 | cost = 1.445711
# [RC=14] Iteration  73 | cost = 1.482522
# [RC=14] Iteration  74 | cost = 1.511447
# [RC=14] Iteration  75 | cost = 1.501759
# [RC=14] Iteration  76 | cost = 1.569495
# [RC=14] Iteration  77 | cost = 1.421610
# [RC=14] Iteration  78 | cost = 1.453276
# [RC=14] Iteration  79 | cost = 1.537561
# [RC=14] Iteration  80 | cost = 1.461894
# [RC=14] Iteration  81 | cost = 1.425993
# [RC=14] Iteration  82 | cost = 1.481825
# [RC=14] Iteration  83 | cost = 1.561669
# [RC=14] Iteration  84 | cost = 1.421610
# [RC=14] Iteration  85 | cost = 1.548244
# [RC=14] Iteration  86 | cost = 2.319446
# [RC=14] Iteration  87 | cost = 1.023732
# [RC=14] Iteration  88 | cost = 0.519628
# [RC=14] Iteration  89 | cost = 0.509451
# [RC=14] Iteration  90 | cost = 0.525647
# [RC=14] Iteration  91 | cost = 0.383524
# [RC=14] Iteration  92 | cost = 0.422135
# [RC=14] Iteration  93 | cost = 0.302960
# [RC=14] Iteration  94 | cost = 0.291605
# [RC=14] Iteration  95 | cost = 0.231770
# [RC=14] Iteration  96 | cost = 0.219066
# [RC=14] Iteration  97 | cost = 0.177275
# [RC=14] Iteration  98 | cost = 0.182618
# [RC=14] Iteration  99 | cost = 0.161352
# [RC=14] Iteration 100 | cost = 0.161450
# [RC=14] Iteration 101 | cost = 0.141601
# [RC=14] Iteration 102 | cost = 0.141611
# [RC=14] Iteration 103 | cost = 0.096519
# [RC=14] Iteration 104 | cost = 0.091383
# [RC=14] Iteration 105 | cost = 0.059022
# [RC=14] Iteration 106 | cost = 0.055941
# [RC=14] Iteration 107 | cost = 0.039381
# [RC=14] Iteration 108 | cost = 0.041380
# [RC=14] Iteration 109 | cost = 0.025499
# [RC=14] Iteration 110 | cost = 0.028434
# [RC=14] Iteration 111 | cost = 0.021539
# [RC=14] Iteration 112 | cost = 0.022716
# [RC=14] Iteration 113 | cost = 0.007279
# [RC=14] Iteration 114 | cost = 0.007290
# [RC=14] Iteration 115 | cost = 0.001411
# [RC=14] Iteration 116 | cost = 0.001416
# [RC=14] Iteration 117 | cost = 0.000456
# [RC=14] Iteration 118 | cost = 0.000454
# [RC=14] Iteration 119 | cost = 0.007555
# [RC=14] Iteration 120 | cost = 0.000481
# [RC=14] Iteration 121 | cost = 0.009031
# [RC=14] Iteration 122 | cost = 0.000472
# [RC=14] Iteration 123 | cost = 0.009306
# [RC=14] Iteration 124 | cost = 0.000443
# [RC=14] Iteration 125 | cost = 0.023915
# [RC=14] Iteration 126 | cost = 0.000412
# [RC=14] Iteration 127 | cost = 0.002435
# [RC=14] Iteration 128 | cost = 0.000411
# [RC=14] Iteration 129 | cost = 0.011272
# [RC=14] Iteration 130 | cost = 0.000425
# [RC=14] Iteration 131 | cost = 0.004886
# [RC=14] Iteration 132 | cost = 0.000413
# [RC=14] Iteration 133 | cost = 0.002483
# [RC=14] Iteration 134 | cost = 0.000411
# [RC=14] Iteration 135 | cost = 0.003895
# [RC=14] Iteration 136 | cost = 0.000407
# [RC=14] Iteration 137 | cost = 0.004347
# [RC=14] Iteration 138 | cost = 0.000407
# [RC=14] Iteration 139 | cost = 0.007240
# [RC=14] Iteration 140 | cost = 0.000423
# [RC=14] Iteration 141 | cost = 0.006259
# [RC=14] Iteration 142 | cost = 0.000386
# [RC=14] Iteration 143 | cost = 0.007772
# [RC=14] Iteration 144 | cost = 0.000397
# [RC=14] Iteration 145 | cost = 0.004050
# [RC=14] Iteration 146 | cost = 0.000403
# [RC=14] Iteration 147 | cost = 0.002924
# [RC=14] Iteration 148 | cost = 0.000393
# [RC=14] Iteration 149 | cost = 0.012445
# [RC=14] Iteration 150 | cost = 0.000391
# Précision test re-uploading (RC=14) : 49.00%
#
# Meilleur RC_REUPLOAD = 8
# Meilleure précision test re-uploading : 63.50%

# %%
if USE_REUPLOAD:
    print(f"Circuit re-uploading appris (meilleur RC={best_rc}) :")
    qc_reupload = create_reupload_circuit(X_train[0], theta_re, omega_re, best_rc, measure=False)
    display(qc_reupload.draw("mpl"))
# Out:
# Circuit re-uploading appris (meilleur RC=8) :

# %%
if USE_REUPLOAD:
    plt.figure(figsize=(7, 4))
    plt.plot(reupload_results["rc_values"], reupload_results["accuracies"], marker="o")
    plt.xlabel("Nombre de couches re-uploading (RC_REUPLOAD)")
    plt.ylabel("Accuracy test")
    plt.title("Accuracy du modèle re-uploading en fonction de RC_REUPLOAD")
    plt.ylim(0, 1)
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
def plot_3d_reupload():
    pred1 = X_test[y_pred_reupload == 1]
    pred0 = X_test[y_pred_reupload == 0]

    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(pred0[:, 0], pred0[:, 1], pred0[:, 2], color='red', label='pred0', alpha=0.7)
    ax.scatter(pred1[:, 0], pred1[:, 1], pred1[:, 2], color='blue', label='pred1', alpha=0.7)

    ax.set_xlabel('x1')
    ax.set_ylabel('x2')
    ax.set_zlabel('x3')
    ax.set_title('Prédictions du modèle re-uploading (1 qubit)')
    ax.legend()
    plt.show()

if USE_REUPLOAD and N_DIM == 3:
    plot_3d_reupload()

# %%
if USE_REUPLOAD:
    print("=== Comparaison rapide ===")
    print(f"Re-uploading   (1 qubit)  : {reupload_accuracy * 100:.2f}%")
# Out:
# === Comparaison rapide ===
# Re-uploading   (1 qubit)  : 63.50%

# %% [markdown]
# ## AdaBoost sur le re-uploading (nombre de classifieurs variable)
#
# On fixe la profondeur du weak learner au meilleur `RC_REUPLOAD` trouvé (`best_rc`),
# puis on fait varier le nombre de classifieurs dans AdaBoost pour tracer l'accuracy finale.

# %%
N_ESTIMATORS_VALUES = [1, 2, 3, 4, 5, 6, 8, 10]
MAXITER_WEAK_REUPLOAD = MAXITER_REUPLOAD

def reupload_cost_weighted_samples(params, X, y, sample_weights, rc_reupload):
    theta = params[:3 * rc_reupload].reshape(rc_reupload, 3)
    omega = params[3 * rc_reupload:].reshape(rc_reupload, 3)

    circuits = [create_reupload_circuit(x, theta, omega, rc_reupload, measure=False) for x in X]
    probs = get_reupload_probs_batch(circuits)

    total_cost = 0.0
    for i, y_target in enumerate(y):
        p0, p1 = probs[i]
        y_expected = (1.0, 0.0) if y_target == 0 else (0.0, 1.0)
        total_cost += sample_weights[i] * ((p0 - y_expected[0])**2 + (p1 - y_expected[1])**2)

    return 0.5 * total_cost / np.sum(sample_weights)

def optimize_reupload_weak_learner(X, y, sample_weights, rc_reupload, seed):
    rng = np.random.default_rng(seed)
    init = rng.uniform(-np.pi, np.pi, size=6 * rc_reupload)

    res = minimize(
        reupload_cost_weighted_samples,
        init,
        args=(X, y, sample_weights, rc_reupload),
        method="COBYLA",
        options={"maxiter": MAXITER_WEAK_REUPLOAD},
    )

    theta = res.x[:3 * rc_reupload].reshape(rc_reupload, 3)
    omega = res.x[3 * rc_reupload:].reshape(rc_reupload, 3)
    return theta, omega, res.fun

def train_adaboost_reupload(X_train, y_train, rc_reupload, n_estimators):
    n_samples = len(y_train)
    weights = np.ones(n_samples) / n_samples
    estimators = []

    for i in range(n_estimators):
        theta, omega, cost = optimize_reupload_weak_learner(
            X_train, y_train, weights, rc_reupload, seed=SEED + 100 + i
        )

        y_pred = predict_reupload_batch(X_train, theta, omega, rc_reupload)
        incorrect = (y_pred != y_train).astype(float)
        eps = np.dot(weights, incorrect)
        eps = np.clip(eps, 1e-10, 1 - 1e-10)

        alpha = 0.5 * np.log((1 - eps) / eps)

        y_signed = np.where(y_train == 0, -1.0, 1.0)
        h_signed = np.where(y_pred == 0, -1.0, 1.0)
        weights *= np.exp(-alpha * y_signed * h_signed)
        weights /= np.sum(weights)

        estimators.append((theta, omega, alpha))
        print(f"round {i + 1:02d}/{n_estimators:02d} | cost={cost:.4f} eps={eps:.4f} alpha={alpha:.4f}")

    return estimators

def predict_adaboost_reupload(X, estimators, rc_reupload):
    scores = np.zeros(len(X))
    for theta, omega, alpha in estimators:
        h_signed = np.where(predict_reupload_batch(X, theta, omega, rc_reupload) == 0, -1.0, 1.0)
        scores += alpha * h_signed
    return np.where(scores >= 0, 1, 0)

def evaluate_adaboost_reupload(X, y, estimators, rc_reupload):
    y_pred = predict_adaboost_reupload(X, estimators, rc_reupload)
    accuracy = np.mean(y_pred == y)
    return accuracy, y_pred

if USE_REUPLOAD:
    adaboost_results = {"n_estimators": [], "accuracies": []}

    print(f"Balayage AdaBoost sur meilleur RC_REUPLOAD={best_rc}")
    for n_est in N_ESTIMATORS_VALUES:
        print(f"\n=== AdaBoost avec {n_est} classifieurs ===")
        estimators_ab = train_adaboost_reupload(X_train, y_train, rc_reupload=best_rc, n_estimators=n_est)
        acc_ab, _ = evaluate_adaboost_reupload(X_test, y_test, estimators_ab, rc_reupload=best_rc)

        adaboost_results["n_estimators"].append(n_est)
        adaboost_results["accuracies"].append(acc_ab)
        print(f"Accuracy test AdaBoost ({n_est} classifieurs) : {100 * acc_ab:.2f}%")
else:
    print("Bloc AdaBoost non exécuté car N_DIM != 3")
# Out:
# Balayage AdaBoost sur meilleur RC_REUPLOAD=8
#
# === AdaBoost avec 1 classifieurs ===
# round 01/01 | cost=0.1748 eps=0.2700 alpha=0.4973
# Accuracy test AdaBoost (1 classifieurs) : 65.50%
#
# === AdaBoost avec 2 classifieurs ===
# round 01/02 | cost=0.1748 eps=0.2700 alpha=0.4973
# round 02/02 | cost=0.1949 eps=0.2855 alpha=0.4586
# Accuracy test AdaBoost (2 classifieurs) : 65.50%
#
# === AdaBoost avec 3 classifieurs ===
# round 01/03 | cost=0.1748 eps=0.2700 alpha=0.4973
# round 02/03 | cost=0.1949 eps=0.2855 alpha=0.4586
# round 03/03 | cost=0.1929 eps=0.2722 alpha=0.4918
# Accuracy test AdaBoost (3 classifieurs) : 76.00%
#
# === AdaBoost avec 4 classifieurs ===
# round 01/04 | cost=0.1748 eps=0.2700 alpha=0.4973
# round 02/04 | cost=0.1949 eps=0.2855 alpha=0.4586
# round 03/04 | cost=0.1929 eps=0.2722 alpha=0.4918
# round 04/04 | cost=0.1700 eps=0.2754 alpha=0.4837
# Accuracy test AdaBoost (4 classifieurs) : 78.00%
#
# === AdaBoost avec 5 classifieurs ===
# round 01/05 | cost=0.1748 eps=0.2700 alpha=0.4973
# round 02/05 | cost=0.1949 eps=0.2855 alpha=0.4586
# round 03/05 | cost=0.1929 eps=0.2722 alpha=0.4918
# round 04/05 | cost=0.1700 eps=0.2754 alpha=0.4837
# round 05/05 | cost=0.1645 eps=0.2424 alpha=0.5698
# Accuracy test AdaBoost (5 classifieurs) : 82.50%
#
# === AdaBoost avec 6 classifieurs ===
# round 01/06 | cost=0.1748 eps=0.2700 alpha=0.4973
# round 02/06 | cost=0.1949 eps=0.2855 alpha=0.4586
# round 03/06 | cost=0.1929 eps=0.2722 alpha=0.4918
# round 04/06 | cost=0.1700 eps=0.2754 alpha=0.4837
# round 05/06 | cost=0.1645 eps=0.2424 alpha=0.5698
# round 06/06 | cost=0.1833 eps=0.2677 alpha=0.5031
# Accuracy test AdaBoost (6 classifieurs) : 82.50%
#
# === AdaBoost avec 8 classifieurs ===
# round 01/08 | cost=0.1748 eps=0.2700 alpha=0.4973
# round 02/08 | cost=0.1949 eps=0.2855 alpha=0.4586
# round 03/08 | cost=0.1929 eps=0.2722 alpha=0.4918
# round 04/08 | cost=0.1700 eps=0.2754 alpha=0.4837
# round 05/08 | cost=0.1645 eps=0.2424 alpha=0.5698
# round 06/08 | cost=0.1833 eps=0.2677 alpha=0.5031
# round 07/08 | cost=0.1650 eps=0.2521 alpha=0.5436
# round 08/08 | cost=0.1682 eps=0.2452 alpha=0.5621
# Accuracy test AdaBoost (8 classifieurs) : 86.50%
#
# === AdaBoost avec 10 classifieurs ===
# round 01/10 | cost=0.1748 eps=0.2700 alpha=0.4973
# round 02/10 | cost=0.1949 eps=0.2855 alpha=0.4586
# round 03/10 | cost=0.1929 eps=0.2722 alpha=0.4918
# round 04/10 | cost=0.1700 eps=0.2754 alpha=0.4837
# round 05/10 | cost=0.1645 eps=0.2424 alpha=0.5698
# round 06/10 | cost=0.1833 eps=0.2677 alpha=0.5031
# round 07/10 | cost=0.1650 eps=0.2521 alpha=0.5436
# round 08/10 | cost=0.1682 eps=0.2452 alpha=0.5621
# round 09/10 | cost=0.2056 eps=0.2837 alpha=0.4631
# round 10/10 | cost=0.2294 eps=0.3659 alpha=0.2750
# Accuracy test AdaBoost (10 classifieurs) : 86.50%

# %%
if USE_REUPLOAD:
    plt.figure(figsize=(7, 4))
    plt.plot(adaboost_results["n_estimators"], adaboost_results["accuracies"], marker="o")
    plt.xlabel("Nombre de classifieurs AdaBoost")
    plt.ylabel("Accuracy test")
    plt.title("Accuracy AdaBoost (base re-uploading 1 qubit)\n en fonction du nombre de classifieurs")
    plt.ylim(0, 1)
    plt.grid(True, alpha=0.3)
    plt.show()

    best_i = int(np.argmax(adaboost_results["accuracies"]))
    best_n = adaboost_results["n_estimators"][best_i]
    best_acc = adaboost_results["accuracies"][best_i]
    print(f"Meilleur nombre de classifieurs AdaBoost : {best_n}")
    print(f"Meilleure accuracy AdaBoost : {100 * best_acc:.2f}%")
# Out:
# Meilleur nombre de classifieurs AdaBoost : 8
# Meilleure accuracy AdaBoost : 86.50%
